# %% [markdown]
# # SUMMARY
#
# This notebook builds on the great pipeline [introduced](https://www.kaggle.com/yasufuminakama/inchi-resnet-lstm-with-attention-starter) by Y. Nakama and [adapted to EfficientNets](https://www.kaggle.com/konradb/model-train-efficientnet) by Konrad Banachewicz. The notebook further extendens the pipeline by adding support for multi-layer LSTM in the decoder part. Most of the code changes are concentrated in the model class. Please credit the original authors for their contributions.
#
# This is training notebook. Inference with multi-layer LSTM decoder is demonstarted [in this notebook](https://www.kaggle.com/kozodoi/efficientnet-multi-layer-lstm-inference).
#
# ### References:
#
# - [starter notebook from Y. Nakama](https://www.kaggle.com/yasufuminakama/inchi-resnet-lstm-with-attention-starter)
# - [adapted notebook from Konrad](https://www.kaggle.com/yasufuminakama/inchi-resnet-lstm-with-attention-starter)
# - [PyTorch tutorial on image captioning](https://github.com/sgrvinod/a-PyTorch-Tutorial-to-Image-Captioning)
# - [two-layer RNN implementation](https://github.com/sgrvinod/a-PyTorch-Tutorial-to-Image-Captioning/pull/79)

# %%
import os
from matplotlib import pyplot as plt

OUTPUT_DIR = './'
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)
    
import numpy as np
import pandas as pd
import torch

import sys
sys.path.append('../input/timm-pytorch-image-models/pytorch-image-models-master')

import os
import gc
import re
import math
import time
import random
import shutil
import pickle
from pathlib import Path
from contextlib import contextmanager
from collections import defaultdict, Counter

import scipy as sp
import numpy as np
import pandas as pd
from tqdm.auto import tqdm

import Levenshtein
from sklearn import preprocessing
from sklearn.model_selection import StratifiedKFold, GroupKFold, KFold

from functools import partial

import cv2
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam, SGD
import torchvision.models as models
from torch.nn.parameter import Parameter
from torch.utils.data import DataLoader, Dataset
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts, CosineAnnealingLR, ReduceLROnPlateau

from albumentations import (
    Compose, OneOf, Normalize, Resize, RandomResizedCrop, RandomCrop, HorizontalFlip, VerticalFlip, 
    RandomBrightness, RandomContrast, RandomBrightnessContrast, Rotate, ShiftScaleRotate, Cutout, 
    IAAAdditiveGaussianNoise, Transpose, Blur
    )
from albumentations.pytorch import ToTensorV2
from albumentations import ImageOnlyTransform

import timm

from aoa import AoA_Refiner_Core, clones

import warnings 
warnings.filterwarnings('ignore')

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# CFG class now includes a new parameter: `decoder_layers`. For illustration purposes, I am running a two-layer LSTM for 1 epoch on 100k images.

# %%
#  n_channels_dict = {'efficientnet-b0': 1280, 'efficientnet-b1': 1280, 'efficientnet-b2': 1408,
#   'efficientnet-b3': 1536, 'efficientnet-b4': 1792, 'efficientnet-b5': 2048,
#   'efficientnet-b6': 2304, 'efficientnet-b7': 2560}

# This is not, to put it mildly, the most elegant solution ever - but I ran into some trouble 
# with checking the size of feature spaces programmatically inside the CFG definition.

class CFG:
    debug          = False
    apex           = False
    max_len        = 275
    print_freq     = 100
    num_workers    = 16
    model_name     = 'efficientnet_b2'
    enc_size       = 1408
    samp_size      = 1000
    size           = 288
    scheduler      = 'CosineAnnealingLR' 
    epochs         = 2
    n_fold         = 20
    batch_size     = 64
    T_max          = int(((2424186 * (n_fold-1)/n_fold) / batch_size) * epochs )
    encoder_lr     = 5e-5#1e-4
    decoder_lr     = 1e-4#4e-4
    min_lr         = 1e-7
    weight_decay   = 1e-6
    gradient_accumulation_steps = 1
    max_grad_norm  = 10
    attention_dim  = 256
    embed_dim      = 512
    decoder_dim    = 512
    decoder_layers = 2     # number of LSTM layers
    dropout        = 0.5
    seed           = 32
    trn_fold       = 0 
    train          = True
    train_path     = '../data/processed_train/'
    test_path      = '../data/processed_test/'
    prep_path      = './'
    prev_models     = ['./efficientnet_b2_fold0_best_aoa.pth']
    aoa_use_ff     = 0
    num_heads = 8
    ensemble_num = 1

# %% [markdown]
# # Functions

# %%
class Tokenizer(object):
    
    def __init__(self):
        self.stoi = {}
        self.itos = {}

    def __len__(self):
        return len(self.stoi)
    
    def fit_on_texts(self, texts):
        vocab = set()
        for text in texts:
            vocab.update(text.split(' '))
        vocab = sorted(vocab)
        vocab.append('<sos>')
        vocab.append('<eos>')
        vocab.append('<pad>')
        for i, s in enumerate(vocab):
            self.stoi[s] = i
        self.itos = {item[1]: item[0] for item in self.stoi.items()}
        
    def text_to_sequence(self, text):
        sequence = []
        sequence.append(self.stoi['<sos>'])
        for s in text.split(' '):
            sequence.append(self.stoi[s])
        sequence.append(self.stoi['<eos>'])
        return sequence
    
    def texts_to_sequences(self, texts):
        sequences = []
        for text in texts:
            sequence = self.text_to_sequence(text)
            sequences.append(sequence)
        return sequences

    def sequence_to_text(self, sequence):
        return ''.join(list(map(lambda i: self.itos[i], sequence)))
    
    def sequences_to_texts(self, sequences):
        texts = []
        for sequence in sequences:
            text = self.sequence_to_text(sequence)
            texts.append(text)
        return texts
    
    def predict_caption(self, sequence):
        caption = ''
        for i in sequence:
            if i == self.stoi['<eos>'] or i == self.stoi['<pad>']:
                break
            caption += self.itos[i]
        return caption
    
    def predict_captions(self, sequences):
        captions = []
        for sequence in sequences:
            caption = self.predict_caption(sequence)
            captions.append(caption)
        return captions

tokenizer = torch.load(CFG.prep_path + 'tokenizer.pth')
print(f"tokenizer.stoi: {tokenizer.stoi}")
# Out:
# tokenizer.stoi: {'(': 0, ')': 1, '+': 2, ',': 3, '-': 4, '/b': 5, '/c': 6, '/h': 7, '/i': 8, '/m': 9, '/s': 10, '/t': 11, '0': 12, '1': 13, '10': 14, '100': 15, '101': 16, '102': 17, '103': 18, '104': 19, '105': 20, '106': 21, '107': 22, '108': 23, '109': 24, '11': 25, '110': 26, '111': 27, '112': 28, '113': 29, '114': 30, '115': 31, '116': 32, '117': 33, '118': 34, '119': 35, '12': 36, '120': 37, '121': 38, '122': 39, '123': 40, '124': 41, '125': 42, '126': 43, '127': 44, '128': 45, '129': 46, '13': 47, '130': 48, '131': 49, '132': 50, '133': 51, '134': 52, '135': 53, '136': 54, '137': 55, '138': 56, '139': 57, '14': 58, '140': 59, '141': 60, '142': 61, '143': 62, '144': 63, '145': 64, '146': 65, '147': 66, '148': 67, '149': 68, '15': 69, '150': 70, '151': 71, '152': 72, '153': 73, '154': 74, '155': 75, '156': 76, '157': 77, '158': 78, '159': 79, '16': 80, '161': 81, '163': 82, '165': 83, '167': 84, '17': 85, '18': 86, '19': 87, '2': 88, '20': 89, '21': 90, '22': 91, '23': 92, '24': 93, '25': 94, '26': 95, '27': 96, '28': 97, '29': 98, '3': 99, '30': 100, '31': 101, '32': 102, '33': 103, '34': 104, '35': 105, '36': 106, '37': 107, '38': 108, '39': 109, '4': 110, '40': 111, '41': 112, '42': 113, '43': 114, '44': 115, '45': 116, '46': 117, '47': 118, '48': 119, '49': 120, '5': 121, '50': 122, '51': 123, '52': 124, '53': 125, '54': 126, '55': 127, '56': 128, '57': 129, '58': 130, '59': 131, '6': 132, '60': 133, '61': 134, '62': 135, '63': 136, '64': 137, '65': 138, '66': 139, '67': 140, '68': 141, '69': 142, '7': 143, '70': 144, '71': 145, '72': 146, '73': 147, '74': 148, '75': 149, '76': 150, '77': 151, '78': 152, '79': 153, '8': 154, '80': 155, '81': 156, '82': 157, '83': 158, '84': 159, '85': 160, '86': 161, '87': 162, '88': 163, '89': 164, '9': 165, '90': 166, '91': 167, '92': 168, '93': 169, '94': 170, '95': 171, '96': 172, '97': 173, '98': 174, '99': 175, 'B': 176, 'Br': 177, 'C': 178, 'Cl': 179, 'D': 180, 'F': 181, 'H': 182, 'I': 183, 'N': 184, 'O': 185, 'P': 186, 'S': 187, 'Si': 188, 'T': 189, '<sos>': 190, '<eos>': 191, '<pad>': 192}

# %%
def get_score(y_true, y_pred):
    scores = []
    for true, pred in zip(y_true, y_pred):
        score = Levenshtein.distance(true, pred)
        scores.append(score)
    avg_score = np.mean(scores)
    return avg_score


def init_logger(log_file=OUTPUT_DIR+'train_aoa_finetune1.log'):
    from logging import getLogger, INFO, FileHandler,  Formatter,  StreamHandler
    logger = getLogger(__name__)
    logger.setLevel(INFO)
    handler1 = StreamHandler()
    handler1.setFormatter(Formatter("%(message)s"))
    handler2 = FileHandler(filename=log_file)
    handler2.setFormatter(Formatter("%(message)s"))
    logger.addHandler(handler1)
    logger.addHandler(handler2)
    return logger

LOGGER = init_logger()


def seed_torch(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

seed_torch(seed = CFG.seed)

# %%
# ====================================================
# Dataset
# ====================================================

class TrainDataset(Dataset):
    def __init__(self, df, tokenizer, transform=None):
        super().__init__()
        self.df         = df
        self.tokenizer  = tokenizer
        self.file_paths = df['file_path'].values
        self.labels     = df['InChI_text'].values
        self.transform  = transform
    
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        file_path = self.file_paths[idx]
        image = cv2.imread(file_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB).astype(np.float32)
        if self.transform:
            augmented = self.transform(image = image)
            image     = augmented['image']
        label = self.labels[idx]
        label = self.tokenizer.text_to_sequence(label)
        label_length = len(label)
        label_length = torch.LongTensor([label_length])
        return image, torch.LongTensor(label), label_length
    

class TestDataset(Dataset):
    def __init__(self, df, transform=None):
        super().__init__()
        self.df = df
        self.file_paths = df['file_path'].values
        self.transform = transform
    
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        file_path = self.file_paths[idx]
        image = cv2.imread(file_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB).astype(np.float32)
        if self.transform:
            augmented = self.transform(image=image)
            image = augmented['image']
        return image

# %%
def bms_collate(batch):
    imgs, labels, label_lengths = [], [], []
    for data_point in batch:
        imgs.append(data_point[0])
        labels.append(data_point[1])
        label_lengths.append(data_point[2])
    labels = pad_sequence(labels, batch_first = True, padding_value = tokenizer.stoi["<pad>"])
    return torch.stack(imgs), labels, torch.stack(label_lengths).reshape(-1, 1)

# %%
####### CNN ENCODER

class Encoder(nn.Module):
    def __init__(self, model_name = CFG.model_name, pretrained = False):
        super().__init__()
        self.cnn = timm.create_model(model_name, pretrained = pretrained)

    def forward(self, x):
        bs       = x.size(0)
        features = self.cnn.forward_features(x)
        features = features.permute(0, 2, 3, 1)
        return features

# %%
# ###### CNN ENCODER
# class Encoder(nn.Module):
#     def __init__(self, model_name = CFG.model_name, opt = CFG, pretrained = False):
#         super().__init__()
#         cnn = timm.create_model(model_name, pretrained = False)
#         self.cnns = clones(cnn, opt.ensemble_num)
#         self.refiner = AoA_Refiner_Core(opt.num_heads, opt.enc_size, opt.aoa_use_ff)
        
#     def forward(self, x):
#         bs       = x.size(0)
#         features = torch.mean(torch.stack([enc.forward_features(x) for enc in self.cnns]), dim=0)
#         features = features.permute(0, 2, 3, 1)
#         features = features.view(features.shape[0],-1, features.shape[-1])
#         features = self.refiner(features, None)
#         return features

class Refiner(nn.Module):
    def __init__(self, opt):
        super().__init__()
        self.refiner = AoA_Refiner_Core(opt.num_heads, opt.enc_size, opt.aoa_use_ff)
    
    def forward(self, x):
        x = self.refiner(x, None)
        return x

# %% [markdown]
# The class `DecoderWithAttention` is updated to support a multi-layer LSTM.

# %%
####### RNN DECODER
# attention module
class Attention(nn.Module):
    '''
    Attention network for calculate attention value
    '''
    def __init__(self, encoder_dim, decoder_dim, attention_dim):
        '''
        :param encoder_dim: input size of encoder network
        :param decoder_dim: input size of decoder network
        :param attention_dim: input size of attention network
        '''
        super(Attention, self).__init__()
        self.encoder_att = nn.Linear(encoder_dim, attention_dim)  # linear layer to transform encoded image
        self.decoder_att = nn.Linear(decoder_dim, attention_dim)  # linear layer to transform decoder's output
        self.full_att    = nn.Linear(attention_dim, 1)            # linear layer to calculate values to be softmax-ed
        self.relu        = nn.ReLU()
        self.softmax     = nn.Softmax(dim = 1)  # softmax layer to calculate weights

    def forward(self, encoder_out, decoder_hidden):
        att1  = self.encoder_att(encoder_out)     # (batch_size, num_pixels, attention_dim)
        att2  = self.decoder_att(decoder_hidden)  # (batch_size, attention_dim)
        att   = self.full_att(self.relu(att1 + att2.unsqueeze(1))).squeeze(2)  # (batch_size, num_pixels)
        alpha = self.softmax(att)                 # (batch_size, num_pixels)
        attention_weighted_encoding = (encoder_out * alpha.unsqueeze(2)).sum(dim = 1)  # (batch_size, encoder_dim)
        return attention_weighted_encoding, alpha
    
    
# custom LSTM cell
def LSTMCell(input_size, hidden_size, **kwargs):
    m = nn.LSTMCell(input_size, hidden_size, **kwargs)
    for name, param in m.named_parameters():
        if 'weight' in name or 'bias' in name:
            param.data.uniform_(-0.1, 0.1)
    return m


# decoder
class DecoderWithAttention(nn.Module):
    '''
    Decoder network with attention network used for training
    '''

    def __init__(self, attention_dim, embed_dim, decoder_dim, vocab_size, device, encoder_dim, dropout, num_layers, opt):
        '''
        :param attention_dim: input size of attention network
        :param embed_dim: input size of embedding network
        :param decoder_dim: input size of decoder network
        :param vocab_size: total number of characters used in training
        :param encoder_dim: input size of encoder network
        :param num_layers: number of the LSTM layers
        :param dropout: dropout rate
        '''
        super(DecoderWithAttention, self).__init__()
        self.encoder_dim   = encoder_dim
        self.attention_dim = attention_dim
        self.embed_dim     = embed_dim
        self.decoder_dim   = decoder_dim
        self.vocab_size    = vocab_size
        self.dropout       = dropout
        self.num_layers    = num_layers
        self.device        = device
        self.attention     = Attention(encoder_dim, decoder_dim, attention_dim)  # attention network
        self.embedding     = nn.Embedding(vocab_size, embed_dim)                 # embedding layer
        self.dropout       = nn.Dropout(p = self.dropout)
        self.decode_step   = nn.ModuleList([LSTMCell(embed_dim + encoder_dim if layer == 0 else embed_dim, embed_dim) for layer in range(self.num_layers)]) # decoding LSTMCell        
        self.init_h        = nn.Linear(encoder_dim, decoder_dim)  # linear layer to find initial hidden state of LSTMCell
        self.init_c        = nn.Linear(encoder_dim, decoder_dim)  # linear layer to find initial cell state of LSTMCell
        self.f_beta        = nn.Linear(decoder_dim, encoder_dim)  # linear layer to create a sigmoid-activated gate
        self.sigmoid       = nn.Sigmoid()
        self.fc            = nn.Linear(decoder_dim, vocab_size)  # linear layer to find scores over vocabulary
        self.refiner = Refiner(opt)
        self.init_weights()                                      # initialize some layers with the uniform distribution

    def init_weights(self):
        self.embedding.weight.data.uniform_(-0.1, 0.1)
        self.fc.bias.data.fill_(0)
        self.fc.weight.data.uniform_(-0.1, 0.1)

    def load_pretrained_embeddings(self, embeddings):
        self.embedding.weight = nn.Parameter(embeddings)

    def fine_tune_embeddings(self, fine_tune = True):
        for p in self.embedding.parameters():
            p.requires_grad = fine_tune

    def init_hidden_state(self, encoder_out):
        mean_encoder_out = encoder_out.mean(dim = 1)
        h = [self.init_h(mean_encoder_out) for i in range(self.num_layers)]  # (batch_size, decoder_dim)
        c = [self.init_c(mean_encoder_out) for i in range(self.num_layers)]
        return h, c

    def forward(self, encoder_out, encoded_captions, caption_lengths):
        '''
        :param encoder_out: output of encoder network
        :param encoded_captions: transformed sequence from character to integer
        :param caption_lengths: length of transformed sequence
        '''
        batch_size       = encoder_out.size(0)
        encoder_dim      = encoder_out.size(-1)
        vocab_size       = self.vocab_size
        encoder_out      = encoder_out.view(batch_size, -1, encoder_dim)  # (batch_size, num_pixels, encoder_dim)
        # encoder_out = encoder_out.mean(dim = 1, keepdim = True)
        encoder_out = self.refiner(encoder_out)
        num_pixels       = encoder_out.size(1)
        caption_lengths, sort_ind = caption_lengths.squeeze(1).sort(dim = 0, descending = True)
        encoder_out      = encoder_out[sort_ind]
        encoded_captions = encoded_captions[sort_ind]
        
        # embedding transformed sequence for vector
        embeddings = self.embedding(encoded_captions)  # (batch_size, max_caption_length, embed_dim)
        
        # Initialize LSTM state, initialize cell_vector and hidden_vector
        prev_h, prev_c = self.init_hidden_state(encoder_out)  # (batch_size, decoder_dim)
        
        # set decode length by caption length - 1 because of omitting start token
        decode_lengths = (caption_lengths - 1).tolist()
        predictions    = torch.zeros(batch_size, max(decode_lengths), vocab_size, device = self.device)
        alphas         = torch.zeros(batch_size, max(decode_lengths), num_pixels, device = self.device)
        
        # predict sequence
        for t in range(max(decode_lengths)):
            batch_size_t = sum([l > t for l in decode_lengths])
            attention_weighted_encoding, alpha = self.attention(encoder_out[:batch_size_t],
                                                                prev_h[-1][:batch_size_t])
            gate = self.sigmoid(self.f_beta(prev_h[-1][:batch_size_t]))  # gating scalar, (batch_size_t, encoder_dim)
            attention_weighted_encoding = gate * attention_weighted_encoding

            input = torch.cat([embeddings[:batch_size_t, t, :], attention_weighted_encoding], dim=1)
            
            for i, rnn in enumerate(self.decode_step):
                # recurrent cell
                h, c = rnn(input, (prev_h[i][:batch_size_t], prev_c[i][:batch_size_t])) # cell_vector and hidden_vector

                # hidden state becomes the input to the next layer
                input = self.dropout(h)

                # save state for next time step
                prev_h[i] = h
                prev_c[i] = c
                
            preds = self.fc(self.dropout(h))  # (batch_size_t, vocab_size)
            predictions[:batch_size_t, t, :] = preds
            alphas[:batch_size_t, t, :]      = alpha
            
        return predictions, encoded_captions, decode_lengths, alphas, sort_ind
    
    def predict(self, encoder_out, decode_lengths, tokenizer):
        
        # size variables
        batch_size  = encoder_out.size(0)
        encoder_dim = encoder_out.size(-1)
        vocab_size  = self.vocab_size
        encoder_out = encoder_out.view(batch_size, -1, encoder_dim)  # (batch_size, num_pixels, encoder_dim)
        encoder_out = self.refiner(encoder_out)
        num_pixels  = encoder_out.size(1)
        
        # embed start tocken for LSTM input
        start_tockens = torch.ones(batch_size, dtype = torch.long, device = self.device) * tokenizer.stoi['<sos>']
        embeddings    = self.embedding(start_tockens)
        
        # initialize hidden state and cell state of LSTM cell
        h, c        = self.init_hidden_state(encoder_out)  # (batch_size, decoder_dim)
        predictions = torch.zeros(batch_size, decode_lengths, vocab_size, device = self.device)
        
        # predict sequence
        end_condition = torch.zeros(batch_size, dtype=torch.long, device = self.device)
        for t in range(decode_lengths):
            awe, alpha = self.attention(encoder_out, h[-1])  # (s, encoder_dim), (s, num_pixels)
            gate       = self.sigmoid(self.f_beta(h[-1]))    # gating scalar, (s, encoder_dim)
            awe        = gate * awe
            
            input = torch.cat([embeddings, awe], dim=1)
 
            for j, rnn in enumerate(self.decode_step):
                at_h, at_c = rnn(input, (h[j], c[j]))  # (s, decoder_dim)
                input = self.dropout(at_h)
                h[j]  = at_h
                c[j]  = at_c
            
            preds = self.fc(self.dropout(h[-1]))  # (batch_size_t, vocab_size)
            predictions[:, t, :] = preds
            end_condition |= (torch.argmax(preds, -1) == tokenizer.stoi["<eos>"])
            if end_condition.sum() == batch_size:
                break
            embeddings = self.embedding(torch.argmax(preds, -1))
        
        return predictions
    
    # beam search
    def forward_step(self, prev_tokens, hidden, encoder_out, function):
        
        h, c = hidden
        #h, c = h.squeeze(0), c.squeeze(0)
        h, c = [hi.squeeze(0) for hi in h], [ci.squeeze(0) for ci in c]
        
        embeddings = self.embedding(prev_tokens)
        if embeddings.dim() == 3:
            embeddings = embeddings.squeeze(1)
            
        awe, alpha = self.attention(encoder_out, h[-1])  # (s, encoder_dim), (s, num_pixels)
        gate       = self.sigmoid(self.f_beta(h[-1]))    # gating scalar, (s, encoder_dim)
        awe        = gate * awe
        
        input = torch.cat([embeddings, awe], dim = 1)
        for j, rnn in enumerate(self.decode_step):
            at_h, at_c = rnn(input, (h[j], c[j]))  # (s, decoder_dim)
            input = self.dropout(at_h)
            h[j]  = at_h
            c[j]  = at_c

        preds = self.fc(self.dropout(h[-1]))  # (batch_size_t, vocab_size)

        #hidden = (h.unsqueeze(0), c.unsqueeze(0))
        hidden = [hi.unsqueeze(0) for hi in h], [ci.unsqueeze(0) for ci in c]
        predicted_softmax = function(preds, dim = 1)
        
        return predicted_softmax, hidden, None

# %%
# Helper functions

class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val   = 0
        self.avg   = 0
        self.sum   = 0
        self.count = 0

    def update(self, val, n=1):
        self.val    = val
        self.sum   += val * n
        self.count += n
        self.avg    = self.sum / self.count


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s   = now - since
    es  = s / (percent)
    rs  = es - s
    return '%s (remain %s)' % (asMinutes(s), asMinutes(rs))


def train_fn(train_loader, encoders, decoder, criterion, 
             encoder_optimizers, decoder_optimizer, epoch,
             encoder_schedulers, decoder_scheduler, device):
    
    batch_time = AverageMeter()
    data_time  = AverageMeter()
    losses     = AverageMeter()
    
    # switch to train mode
    # encoder.train()
    for encoder in encoders:
        encoder.train()
    decoder.train()
    
    start = end = time.time()
    global_step = 0
    
    for step, (images, labels, label_lengths) in enumerate(train_loader):
        
        # measure data loading time
        data_time.update(time.time() - end)
        
        images        = images.to(device)
        labels        = labels.to(device)
        label_lengths = label_lengths.to(device)
        batch_size    = images.size(0)
        
        features = torch.mean(torch.stack([enc(images) for enc in encoders]), dim=0)
        predictions, caps_sorted, decode_lengths, alphas, sort_ind = decoder(features, labels, label_lengths)
        targets     = caps_sorted[:, 1:]
        predictions = pack_padded_sequence(predictions, decode_lengths, batch_first=True).data
        targets     = pack_padded_sequence(targets, decode_lengths, batch_first=True).data
        loss        = criterion(predictions, targets)
        
        # record loss
        losses.update(loss.item(), batch_size)
        if CFG.gradient_accumulation_steps > 1:
            loss = loss / CFG.gradient_accumulation_steps
            
        if CFG.apex:
            with amp.scale_loss(loss, decoder_optimizer) as scaled_loss:
                scaled_loss.backward()
        else:
            loss.backward()
            
        encoder_grad_norm = torch.nn.utils.clip_grad_norm_(encoder.parameters(), CFG.max_grad_norm)
        decoder_grad_norm = torch.nn.utils.clip_grad_norm_(decoder.parameters(), CFG.max_grad_norm)

        for encoder_scheduler in encoder_schedulers:
            encoder_scheduler.step()
        decoder_scheduler.step()
        
        if (step + 1) % CFG.gradient_accumulation_steps == 0:
            for encoder_optimizer in encoder_optimizers:
                encoder_optimizer.step()
                encoder_optimizer.zero_grad()
            decoder_optimizer.step()
            decoder_optimizer.zero_grad()
            global_step += 1
            
        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()
        if step % CFG.print_freq == 0 or step == (len(train_loader)-1):
            print('Epoch: [{0}][{1}/{2}] '
                  'Data {data_time.val:.3f} ({data_time.avg:.3f}) '
                  'Elapsed {remain:s} '
                  'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                  'Encoder Grad: {encoder_grad_norm:.4f}  '
                  'Decoder Grad: {decoder_grad_norm:.4f}  '
                  'Encoder LR: {encoder_lr:.6f}  '
                  'Decoder LR: {decoder_lr:.6f}  '
                  .format(
                   epoch+1, step, len(train_loader), 
                   batch_time        = batch_time,
                   data_time         = data_time, 
                   loss              = losses,
                   remain            = timeSince(start, float(step+1)/len(train_loader)),
                   encoder_grad_norm = encoder_grad_norm,
                   decoder_grad_norm = decoder_grad_norm,
                   encoder_lr=encoder_schedulers[0].get_lr()[0],
                   decoder_lr=decoder_scheduler.get_lr()[0],
                   ))
    return losses.avg


def valid_fn(valid_loader, encoders, decoder, tokenizer, criterion, device):
    
    batch_time = AverageMeter()
    data_time  = AverageMeter()
    
    # switch to evaluation mode
    for encoder in encoders:
        encoder.eval()
    decoder.eval()
    
    text_preds = []
    start = end = time.time()
    
    for step, (images) in enumerate(valid_loader):
        
        # measure data loading time
        data_time.update(time.time() - end)
        
        images     = images.to(device)
        batch_size = images.size(0)
        
        with torch.no_grad():
            features = torch.mean(torch.stack([enc(images) for enc in encoders]), dim=0)
            predictions = decoder.predict(features, CFG.max_len, tokenizer)
            
        predicted_sequence = torch.argmax(predictions.detach().cpu(), -1).numpy()
        _text_preds        = tokenizer.predict_captions(predicted_sequence)
        text_preds.append(_text_preds)
        
        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()
        if step % CFG.print_freq == 0 or step == (len(valid_loader)-1):
            print('EVAL: [{0}/{1}] '
                  'Data {data_time.val:.3f} ({data_time.avg:.3f}) '
                  'Elapsed {remain:s} '
                  .format(
                   step, len(valid_loader), 
                   batch_time = batch_time,
                   data_time  = data_time,
                   remain     = timeSince(start, float(step+1)/len(valid_loader)),
                   ))
            
    text_preds = np.concatenate(text_preds)
    return text_preds

# %%
# ====================================================
# Train loop
# ====================================================
def train_loop(folds, fold):

    LOGGER.info(f"========== fold: {fold} training ==========")

    # ====================================================
    # loader
    # ====================================================
    trn_idx = folds[folds['fold'] != fold].index
    val_idx = folds[folds['fold'] == fold].index

    train_folds  = folds.loc[trn_idx].reset_index(drop = True)
    valid_folds  = folds.loc[val_idx].reset_index(drop = True)
    valid_labels = valid_folds['InChI'].values

    train_dataset = TrainDataset(train_folds, tokenizer, transform = get_transforms(data = 'train'))
    valid_dataset = TestDataset(valid_folds, transform = get_transforms(data = 'valid'))

    train_loader = DataLoader(train_dataset, 
                              batch_size  = CFG.batch_size, 
                              shuffle     = True, 
                              num_workers = CFG.num_workers, 
                              pin_memory  = True,
                              drop_last   = True, 
                              collate_fn  = bms_collate)
    valid_loader = DataLoader(valid_dataset, 
                              batch_size  = CFG.batch_size, 
                              shuffle     = False, 
                              num_workers = CFG.num_workers,
                              pin_memory  = True, 
                              drop_last   = False)
    
    # ====================================================
    # scheduler 
    # ====================================================
    def get_scheduler(optimizer):
        if CFG.scheduler=='ReduceLROnPlateau':
            scheduler = ReduceLROnPlateau(optimizer, 
                                          mode     = 'min', 
                                          factor   = CFG.factor, 
                                          patience = CFG.patience, 
                                          verbose  = True, 
                                          eps      = CFG.eps)
        elif CFG.scheduler=='CosineAnnealingLR':
            scheduler = CosineAnnealingLR(optimizer, 
                                          T_max      = CFG.T_max, 
                                          eta_min    = CFG.min_lr, 
                                          last_epoch = -1)
        elif CFG.scheduler=='CosineAnnealingWarmRestarts':
            scheduler = CosineAnnealingWarmRestarts(optimizer, 
                                                    T_0        = CFG.T_0, 
                                                    T_mult     = 1, 
                                                    eta_min    = CFG.min_lr, 
                                                    last_epoch = -1)
        return scheduler

    # ====================================================
    # model & optimizer
    # ====================================================
    states = torch.load(CFG.prev_models[0],  map_location=torch.device('cpu'))
    
    encoders = [Encoder(CFG.model_name, pretrained = True).to(device) for _ in range(CFG.ensemble_num)]
    for encoder, prev_model in zip(encoders, CFG.prev_models):
        encoder.load_state_dict(torch.load(prev_model,  map_location=torch.device('cpu'))['encoder'])
    # encoder.load_state_dict(states['encoder'])
    # encoders[0].load_state_dict(torch.load(CFG.prev_model,  map_location=torch.device('cpu'))['encoder0'])
    # encoders[1].load_state_dict(torch.load(CFG.prev_model,  map_location=torch.device('cpu'))['encoder1'])
    
    encoder_optimizers = [Adam(encoders[i].parameters(), 
                             lr           = CFG.encoder_lr, 
                             weight_decay = CFG.weight_decay, 
                             amsgrad      = False) for i in range(CFG.ensemble_num)]
#    encoder_optimizer.load_state_dict(states['encoder_optimizer'])
    encoder_schedulers = [get_scheduler(optimizer) for optimizer in encoder_optimizers]
#    encoder_scheduler.load_state_dict(states['encoder_scheduler'])
    
    decoder = DecoderWithAttention(attention_dim = CFG.attention_dim, 
                                   embed_dim     = CFG.embed_dim, 
                                   encoder_dim   = CFG.enc_size,
                                   decoder_dim   = CFG.decoder_dim,
                                   num_layers    = CFG.decoder_layers,
                                   vocab_size    = len(tokenizer), 
                                   dropout       = CFG.dropout, 
                                   device        = device,
                                   opt = CFG)       
    decoder.load_state_dict(states['decoder'])
    decoder.to(device)
    decoder_optimizer = Adam(decoder.parameters(), 
                             lr           = CFG.decoder_lr, 
                             weight_decay = CFG.weight_decay, 
                             amsgrad      = False)
#    decoder_optimizer.load_state_dict(states['decoder_optimizer'])

    decoder_scheduler = get_scheduler(decoder_optimizer)
 #   decoder_scheduler.load_state_dict(states['decoder_scheduler'])

    # ====================================================
    # loop
    # ====================================================
    criterion = nn.CrossEntropyLoss(ignore_index = tokenizer.stoi["<pad>"])

    best_score = np.inf
    best_loss  = np.inf
    
    for epoch in range(6,8):
        
        start_time = time.time()
        
        # train
        avg_loss = train_fn(train_loader, encoders, decoder, criterion, 
                            encoder_optimizers, decoder_optimizer, epoch, 
                            encoder_schedulers, decoder_scheduler, device)

        # eval
        text_preds = valid_fn(valid_loader, encoders, decoder, tokenizer, criterion, device)
        text_preds = [f"InChI=1S/{text}" for text in text_preds]
        LOGGER.info(f"labels: {valid_labels[:5]}")
        LOGGER.info(f"preds: {text_preds[:5]}")
        
        # scoring
        score = get_score(valid_labels, text_preds)
        
        for encoder_scheduler in encoder_schedulers:
            encoder_scheduler.step()
            
        decoder_scheduler.step()

        elapsed = time.time() - start_time

        LOGGER.info(f'Epoch {epoch+1} - avg_train_loss: {avg_loss:.4f}  time: {elapsed:.0f}s')
        LOGGER.info(f'Epoch {epoch+1} - Score: {score:.4f}')
        
        if score < best_score:
            best_score = score
            LOGGER.info(f'Epoch {epoch+1} - Save Best Score: {best_score:.4f} Model')
            torch.save({'encoder': encoders[0].state_dict(),
                        'encoder_optimizer': encoder_optimizers[0].state_dict(), 
                        'encoder_scheduler': encoder_schedulers[0].state_dict(),
                        'decoder': decoder.state_dict(), 
                        'decoder_optimizer': decoder_optimizer.state_dict(), 
                        'decoder_scheduler': decoder_scheduler.state_dict(), 
                        'text_preds': text_preds,
                       },
                        OUTPUT_DIR+f'{CFG.model_name}_fold{fold}_best_aoa_finetune1.pth')

# %%
def get_train_file_path(image_id):

    return CFG.train_path + "{}/{}/{}/{}.png".format(
        image_id[0], image_id[1], image_id[2], image_id 
    )

# %%
# transformations

# - train images: `mean = 0.9871, std = 0.0888`
# - test images:  `mean = 0.9863, std = 0.0921`

train_mean = 1-0.9871
train_std = 0.0888
test_mean = 1-0.9863
test_std = 0.0921

def get_transforms(*, data):
    if data == 'train':
        return Compose([
            RandomResizedCrop(CFG.size, CFG.size, scale=(0.95, 1.05), ratio=(1.0, 1.0), p=0.5),
            Rotate(limit=2, p=0.5),
            Resize(CFG.size, CFG.size),
            Normalize(
                mean=[train_mean, train_mean, train_mean],
                std=[train_std, train_std, train_std],
            ),
            ToTensorV2(),
            
        ])
    
    elif data == 'valid':
        return Compose([
            Resize(CFG.size, CFG.size),
            Normalize(
                mean=[test_mean, test_mean, test_mean],
                std=[test_std, test_std, test_std],
            ),
            ToTensorV2(),
        ])

# %% [markdown]
# # Data

# %%
train = pd.read_pickle(CFG.prep_path + 'train.pkl')

train['file_path'] = train['image_id'].apply(get_train_file_path)

print(f'train.shape: {train.shape}')


if CFG.debug:
    CFG.epochs = 1
    train = train.sample(n = CFG.samp_size, random_state = CFG.seed).reset_index(drop = True)
# Out:
# train.shape: (2424186, 6)

# %%
train_dataset = TrainDataset(train, tokenizer, transform = get_transforms(data='train'))

folds = train.copy()
Fold = StratifiedKFold(n_splits = CFG.n_fold, shuffle = True, random_state = CFG.seed)
for n, (train_index, val_index) in enumerate(Fold.split(folds, folds['InChI_length'])):
    folds.loc[val_index, 'fold'] = int(n)
folds['fold'] = folds['fold'].astype(int)

# %%
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
def visualize_data():
    for i in range(3):
        image, label, label_length = train_dataset[i]
        text = tokenizer.sequence_to_text(label.numpy())
        figure(figsize=(30, 15), dpi=200)
        plt.imshow(image.transpose(0, 1).transpose(1, 2))
        plt.title(f'label: {label}  text: {text}  label_length: {label_length}')
        plt.savefig(str(i) + '.png')
        plt.show()
visualize_data()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Training

# %%
train_loop(folds, CFG.trn_fold)
# Out:
# ========== fold: 0 training ==========
# Epoch: [7][0/35984] Data 2.297 (2.297) Elapsed 0m 4s (remain 2585m 32s) Loss: 0.0677(0.0677) Encoder Grad: 0.2276  Decoder Grad: 0.1518  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][100/35984] Data 0.000 (0.023) Elapsed 1m 24s (remain 500m 8s) Loss: 0.0522(0.0709) Encoder Grad: 0.2600  Decoder Grad: 0.1556  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][200/35984] Data 0.000 (0.012) Elapsed 2m 44s (remain 488m 26s) Loss: 0.0519(0.0701) Encoder Grad: 0.2118  Decoder Grad: 0.1466  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][300/35984] Data 0.000 (0.008) Elapsed 4m 3s (remain 481m 24s) Loss: 0.0504(0.0696) Encoder Grad: 0.2861  Decoder Grad: 0.1383  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][400/35984] Data 0.000 (0.006) Elapsed 5m 22s (remain 476m 23s) Loss: 0.0679(0.0691) Encoder Grad: 0.3351  Decoder Grad: 0.1976  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][500/35984] Data 0.000 (0.005) Elapsed 6m 39s (remain 471m 7s) Loss: 0.0574(0.0689) Encoder Grad: 0.3467  Decoder Grad: 0.1871  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][600/35984] Data 0.000 (0.004) Elapsed 7m 56s (remain 467m 27s) Loss: 0.0846(0.0686) Encoder Grad: 0.4788  Decoder Grad: 0.1788  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][700/35984] Data 0.000 (0.003) Elapsed 9m 13s (remain 464m 33s) Loss: 0.0564(0.0681) Encoder Grad: 0.4390  Decoder Grad: 0.1689  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][800/35984] Data 0.000 (0.003) Elapsed 10m 31s (remain 462m 14s) Loss: 0.0609(0.0682) Encoder Grad: 0.2450  Decoder Grad: 0.1504  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][900/35984] Data 0.000 (0.003) Elapsed 11m 49s (remain 460m 15s) Loss: 0.0985(0.0677) Encoder Grad: 0.3675  Decoder Grad: 0.3080  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][1000/35984] Data 0.000 (0.003) Elapsed 13m 7s (remain 458m 31s) Loss: 0.0948(0.0675) Encoder Grad: 0.5221  Decoder Grad: 0.1451  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][1100/35984] Data 0.000 (0.002) Elapsed 14m 24s (remain 456m 15s) Loss: 0.0684(0.0666) Encoder Grad: 0.3582  Decoder Grad: 0.1738  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][1200/35984] Data 0.000 (0.002) Elapsed 15m 43s (remain 455m 19s) Loss: 0.0477(0.0663) Encoder Grad: 0.2025  Decoder Grad: 0.1195  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][1300/35984] Data 0.000 (0.002) Elapsed 17m 0s (remain 453m 16s) Loss: 0.0883(0.0658) Encoder Grad: 0.6720  Decoder Grad: 0.2591  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][1400/35984] Data 0.000 (0.002) Elapsed 18m 17s (remain 451m 23s) Loss: 0.0485(0.0656) Encoder Grad: 0.5084  Decoder Grad: 0.2778  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][1500/35984] Data 0.000 (0.002) Elapsed 19m 34s (remain 449m 41s) Loss: 0.0621(0.0654) Encoder Grad: 0.4241  Decoder Grad: 0.2208  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][1600/35984] Data 0.000 (0.002) Elapsed 20m 52s (remain 448m 18s) Loss: 0.0631(0.0654) Encoder Grad: 0.4274  Decoder Grad: 0.1788  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][1700/35984] Data 0.000 (0.002) Elapsed 22m 10s (remain 446m 56s) Loss: 0.0451(0.0652) Encoder Grad: 0.2686  Decoder Grad: 0.1387  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][1800/35984] Data 0.000 (0.001) Elapsed 23m 31s (remain 446m 34s) Loss: 0.0747(0.0650) Encoder Grad: 0.4886  Decoder Grad: 0.1502  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][1900/35984] Data 0.000 (0.001) Elapsed 24m 51s (remain 445m 33s) Loss: 0.0501(0.0647) Encoder Grad: 0.2076  Decoder Grad: 0.1160  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][2000/35984] Data 0.000 (0.001) Elapsed 26m 9s (remain 444m 21s) Loss: 0.0708(0.0646) Encoder Grad: 0.2493  Decoder Grad: 0.1522  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][2100/35984] Data 0.000 (0.001) Elapsed 27m 30s (remain 443m 34s) Loss: 0.0476(0.0644) Encoder Grad: 0.1883  Decoder Grad: 0.1432  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][2200/35984] Data 0.000 (0.001) Elapsed 28m 49s (remain 442m 32s) Loss: 0.0500(0.0642) Encoder Grad: 0.2020  Decoder Grad: 0.1170  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][2300/35984] Data 0.000 (0.001) Elapsed 30m 7s (remain 441m 2s) Loss: 0.0683(0.0641) Encoder Grad: 0.2198  Decoder Grad: 0.1560  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][2400/35984] Data 0.000 (0.001) Elapsed 31m 25s (remain 439m 35s) Loss: 0.0547(0.0639) Encoder Grad: 0.2946  Decoder Grad: 0.1448  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][2500/35984] Data 0.000 (0.001) Elapsed 32m 38s (remain 437m 2s) Loss: 0.0811(0.0638) Encoder Grad: 0.2299  Decoder Grad: 0.1502  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][2600/35984] Data 0.000 (0.001) Elapsed 33m 52s (remain 434m 46s) Loss: 0.0534(0.0639) Encoder Grad: 0.3154  Decoder Grad: 0.1482  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][2700/35984] Data 0.000 (0.001) Elapsed 35m 5s (remain 432m 23s) Loss: 0.0765(0.0639) Encoder Grad: 0.3293  Decoder Grad: 0.1818  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][2800/35984] Data 0.000 (0.001) Elapsed 36m 18s (remain 430m 11s) Loss: 0.0435(0.0639) Encoder Grad: 0.2254  Decoder Grad: 0.1346  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][2900/35984] Data 0.000 (0.001) Elapsed 37m 32s (remain 428m 5s) Loss: 0.0589(0.0638) Encoder Grad: 0.3971  Decoder Grad: 0.1291  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][3000/35984] Data 0.000 (0.001) Elapsed 38m 44s (remain 425m 52s) Loss: 0.0430(0.0637) Encoder Grad: 0.2687  Decoder Grad: 0.2043  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][3100/35984] Data 0.000 (0.001) Elapsed 39m 58s (remain 423m 53s) Loss: 0.0533(0.0635) Encoder Grad: 0.2742  Decoder Grad: 0.1340  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][3200/35984] Data 0.000 (0.001) Elapsed 41m 11s (remain 421m 53s) Loss: 0.0593(0.0634) Encoder Grad: 0.3391  Decoder Grad: 0.1965  Encoder LR: 0.000050  Decoder LR: 0.000100
# Epoch: [7][3300/35984] Data 0.000 (0.001) Elapsed 42m 25s (remain 419m 57s) Loss: 0.0660(0.0633) Encoder Grad: 0.3591  Decoder Grad: 0.2067  Encoder LR: 0.000050  Decoder LR: 0.000099
# Epoch: [7][3400/35984] Data 0.000 (0.001) Elapsed 43m 38s (remain 418m 8s) Loss: 0.0551(0.0632) Encoder Grad: 0.3205  Decoder Grad: 0.1863  Encoder LR: 0.000050  Decoder LR: 0.000099
# Epoch: [7][3500/35984] Data 0.000 (0.001) Elapsed 44m 51s (remain 416m 15s) Loss: 0.0350(0.0631) Encoder Grad: 0.2257  Decoder Grad: 0.1248  Encoder LR: 0.000050  Decoder LR: 0.000099
# Epoch: [7][3600/35984] Data 0.000 (0.001) Elapsed 46m 5s (remain 414m 26s) Loss: 0.0735(0.0630) Encoder Grad: 0.1954  Decoder Grad: 0.1500  Encoder LR: 0.000050  Decoder LR: 0.000099
# Epoch: [7][3700/35984] Data 0.000 (0.001) Elapsed 47m 18s (remain 412m 41s) Loss: 0.1073(0.0630) Encoder Grad: 0.3141  Decoder Grad: 0.1442  Encoder LR: 0.000050  Decoder LR: 0.000099
# Epoch: [7][3800/35984] Data 0.000 (0.001) Elapsed 48m 32s (remain 410m 56s) Loss: 0.0518(0.0630) Encoder Grad: 0.4642  Decoder Grad: 0.1561  Encoder LR: 0.000050  Decoder LR: 0.000099
# Epoch: [7][3900/35984] Data 0.000 (0.001) Elapsed 49m 45s (remain 409m 12s) Loss: 0.0442(0.0629) Encoder Grad: 0.5400  Decoder Grad: 0.1973  Encoder LR: 0.000050  Decoder LR: 0.000099
# Epoch: [7][4000/35984] Data 0.000 (0.001) Elapsed 50m 59s (remain 407m 34s) Loss: 0.0682(0.0629) Encoder Grad: 0.3333  Decoder Grad: 0.1864  Encoder LR: 0.000050  Decoder LR: 0.000099
# Epoch: [7][4100/35984] Data 0.000 (0.001) Elapsed 52m 12s (remain 405m 52s) Loss: 0.0751(0.0628) Encoder Grad: 0.2095  Decoder Grad: 0.1492  Encoder LR: 0.000050  Decoder LR: 0.000099
# Epoch: [7][4200/35984] Data 0.000 (0.001) Elapsed 53m 26s (remain 404m 16s) Loss: 0.0507(0.0628) Encoder Grad: 0.2050  Decoder Grad: 0.1341  Encoder LR: 0.000050  Decoder LR: 0.000099
# Epoch: [7][4300/35984] Data 0.000 (0.001) Elapsed 54m 41s (remain 402m 52s) Loss: 0.0403(0.0627) Encoder Grad: 0.4287  Decoder Grad: 0.3707  Encoder LR: 0.000050  Decoder LR: 0.000099
# Epoch: [7][4400/35984] Data 0.000 (0.001) Elapsed 55m 54s (remain 401m 10s) Loss: 0.0381(0.0625) Encoder Grad: 0.2287  Decoder Grad: 0.1733  Encoder LR: 0.000050  Decoder LR: 0.000099
# Epoch: [7][4500/35984] Data 0.000 (0.001) Elapsed 57m 9s (remain 399m 47s) Loss: 0.0574(0.0625) Encoder Grad: 0.3208  Decoder Grad: 0.1658  Encoder LR: 0.000050  Decoder LR: 0.000099
# Epoch: [7][4600/35984] Data 0.000 (0.001) Elapsed 58m 29s (remain 398m 55s) Loss: 0.0393(0.0624) Encoder Grad: 0.1744  Decoder Grad: 0.1049  Encoder LR: 0.000049  Decoder LR: 0.000099
# Epoch: [7][4700/35984] Data 0.000 (0.001) Elapsed 59m 49s (remain 398m 5s) Loss: 0.0438(0.0623) Encoder Grad: 0.2562  Decoder Grad: 0.1520  Encoder LR: 0.000049  Decoder LR: 0.000099
# Epoch: [7][4800/35984] Data 0.000 (0.001) Elapsed 61m 10s (remain 397m 21s) Loss: 0.0521(0.0623) Encoder Grad: 0.3801  Decoder Grad: 0.2174  Encoder LR: 0.000049  Decoder LR: 0.000099
# Epoch: [7][4900/35984] Data 0.000 (0.001) Elapsed 62m 31s (remain 396m 32s) Loss: 0.0754(0.0622) Encoder Grad: 0.6554  Decoder Grad: 0.2654  Encoder LR: 0.000049  Decoder LR: 0.000099
# Epoch: [7][5000/35984] Data 0.000 (0.001) Elapsed 63m 49s (remain 395m 24s) Loss: 0.0566(0.0621) Encoder Grad: 0.3093  Decoder Grad: 0.1261  Encoder LR: 0.000049  Decoder LR: 0.000099
# Epoch: [7][5100/35984] Data 0.000 (0.001) Elapsed 65m 6s (remain 394m 13s) Loss: 0.0558(0.0621) Encoder Grad: 0.4541  Decoder Grad: 0.1908  Encoder LR: 0.000049  Decoder LR: 0.000099
# Epoch: [7][5200/35984] Data 0.000 (0.001) Elapsed 66m 24s (remain 393m 3s) Loss: 0.0343(0.0621) Encoder Grad: 0.1716  Decoder Grad: 0.1243  Encoder LR: 0.000049  Decoder LR: 0.000099
# Epoch: [7][5300/35984] Data 0.000 (0.001) Elapsed 67m 41s (remain 391m 47s) Loss: 0.0557(0.0620) Encoder Grad: 0.4253  Decoder Grad: 0.2094  Encoder LR: 0.000049  Decoder LR: 0.000099
# Epoch: [7][5400/35984] Data 0.000 (0.001) Elapsed 68m 58s (remain 390m 36s) Loss: 0.0245(0.0620) Encoder Grad: 0.1387  Decoder Grad: 0.1013  Encoder LR: 0.000049  Decoder LR: 0.000099
# Epoch: [7][5500/35984] Data 0.000 (0.001) Elapsed 70m 17s (remain 389m 32s) Loss: 0.0381(0.0619) Encoder Grad: 0.3883  Decoder Grad: 0.1712  Encoder LR: 0.000049  Decoder LR: 0.000099
# Epoch: [7][5600/35984] Data 0.000 (0.001) Elapsed 71m 36s (remain 388m 24s) Loss: 0.0403(0.0619) Encoder Grad: 0.2208  Decoder Grad: 0.1786  Encoder LR: 0.000049  Decoder LR: 0.000099
# Epoch: [7][5700/35984] Data 0.000 (0.001) Elapsed 72m 54s (remain 387m 16s) Loss: 0.0463(0.0618) Encoder Grad: 0.4828  Decoder Grad: 0.1637  Encoder LR: 0.000049  Decoder LR: 0.000098
# Epoch: [7][5800/35984] Data 0.000 (0.001) Elapsed 74m 11s (remain 385m 59s) Loss: 0.0482(0.0618) Encoder Grad: 0.2411  Decoder Grad: 0.1722  Encoder LR: 0.000049  Decoder LR: 0.000098
# Epoch: [7][5900/35984] Data 0.000 (0.001) Elapsed 75m 28s (remain 384m 48s) Loss: 0.0835(0.0617) Encoder Grad: 0.3620  Decoder Grad: 0.1635  Encoder LR: 0.000049  Decoder LR: 0.000098
# Epoch: [7][6000/35984] Data 0.000 (0.001) Elapsed 76m 46s (remain 383m 36s) Loss: 0.1039(0.0616) Encoder Grad: 0.2989  Decoder Grad: 0.1600  Encoder LR: 0.000049  Decoder LR: 0.000098
# Epoch: [7][6100/35984] Data 0.000 (0.001) Elapsed 78m 5s (remain 382m 30s) Loss: 0.0470(0.0616) Encoder Grad: 0.3093  Decoder Grad: 0.1614  Encoder LR: 0.000049  Decoder LR: 0.000098
# Epoch: [7][6200/35984] Data 0.000 (0.001) Elapsed 79m 25s (remain 381m 30s) Loss: 0.0751(0.0616) Encoder Grad: 0.3782  Decoder Grad: 0.2420  Encoder LR: 0.000049  Decoder LR: 0.000098
# Epoch: [7][6300/35984] Data 0.000 (0.001) Elapsed 80m 44s (remain 380m 19s) Loss: 0.0796(0.0616) Encoder Grad: 0.2389  Decoder Grad: 0.1656  Encoder LR: 0.000049  Decoder LR: 0.000098
# Epoch: [7][6400/35984] Data 0.000 (0.001) Elapsed 82m 3s (remain 379m 16s) Loss: 0.0617(0.0616) Encoder Grad: 0.3462  Decoder Grad: 0.1415  Encoder LR: 0.000049  Decoder LR: 0.000098
# Epoch: [7][6500/35984] Data 0.000 (0.001) Elapsed 83m 26s (remain 378m 23s) Loss: 0.0632(0.0616) Encoder Grad: 0.4798  Decoder Grad: 0.1604  Encoder LR: 0.000049  Decoder LR: 0.000098
# Epoch: [7][6600/35984] Data 0.000 (0.001) Elapsed 84m 43s (remain 377m 6s) Loss: 0.0475(0.0615) Encoder Grad: 0.3561  Decoder Grad: 0.1270  Encoder LR: 0.000049  Decoder LR: 0.000098
# Epoch: [7][6700/35984] Data 0.000 (0.001) Elapsed 86m 1s (remain 375m 56s) Loss: 0.0461(0.0615) Encoder Grad: 0.2561  Decoder Grad: 0.1351  Encoder LR: 0.000049  Decoder LR: 0.000098
# Epoch: [7][6800/35984] Data 0.000 (0.001) Elapsed 87m 19s (remain 374m 41s) Loss: 0.0425(0.0614) Encoder Grad: 0.2842  Decoder Grad: 0.1529  Encoder LR: 0.000049  Decoder LR: 0.000098
# Epoch: [7][6900/35984] Data 0.000 (0.001) Elapsed 88m 35s (remain 373m 21s) Loss: 0.0571(0.0613) Encoder Grad: 0.2181  Decoder Grad: 0.1483  Encoder LR: 0.000049  Decoder LR: 0.000098
# Epoch: [7][7000/35984] Data 0.000 (0.001) Elapsed 89m 45s (remain 371m 34s) Loss: 0.0401(0.0613) Encoder Grad: 0.3467  Decoder Grad: 0.1443  Encoder LR: 0.000049  Decoder LR: 0.000098
# Epoch: [7][7100/35984] Data 0.000 (0.001) Elapsed 90m 53s (remain 369m 41s) Loss: 0.0393(0.0612) Encoder Grad: 0.1950  Decoder Grad: 0.1183  Encoder LR: 0.000049  Decoder LR: 0.000098
# Epoch: [7][7200/35984] Data 0.000 (0.001) Elapsed 92m 6s (remain 368m 9s) Loss: 0.0610(0.0612) Encoder Grad: 0.2582  Decoder Grad: 0.1544  Encoder LR: 0.000049  Decoder LR: 0.000098
# Epoch: [7][7300/35984] Data 0.000 (0.001) Elapsed 93m 19s (remain 366m 39s) Loss: 0.0629(0.0612) Encoder Grad: 0.2775  Decoder Grad: 0.1399  Encoder LR: 0.000049  Decoder LR: 0.000097
# Epoch: [7][7400/35984] Data 0.000 (0.001) Elapsed 94m 36s (remain 365m 23s) Loss: 0.0432(0.0611) Encoder Grad: 0.3610  Decoder Grad: 0.1767  Encoder LR: 0.000049  Decoder LR: 0.000097
# Epoch: [7][7500/35984] Data 0.000 (0.001) Elapsed 95m 56s (remain 364m 19s) Loss: 0.0453(0.0611) Encoder Grad: 0.2206  Decoder Grad: 0.1453  Encoder LR: 0.000049  Decoder LR: 0.000097
# Epoch: [7][7600/35984] Data 0.000 (0.001) Elapsed 97m 12s (remain 362m 59s) Loss: 0.0382(0.0610) Encoder Grad: 0.2489  Decoder Grad: 0.1932  Encoder LR: 0.000049  Decoder LR: 0.000097
# Epoch: [7][7700/35984] Data 0.000 (0.001) Elapsed 98m 28s (remain 361m 40s) Loss: 0.0637(0.0610) Encoder Grad: 0.5161  Decoder Grad: 0.1876  Encoder LR: 0.000049  Decoder LR: 0.000097
# Epoch: [7][7800/35984] Data 0.000 (0.001) Elapsed 99m 45s (remain 360m 23s) Loss: 0.0474(0.0610) Encoder Grad: 0.2676  Decoder Grad: 0.1578  Encoder LR: 0.000049  Decoder LR: 0.000097
# Epoch: [7][7900/35984] Data 0.000 (0.001) Elapsed 101m 2s (remain 359m 7s) Loss: 0.0550(0.0610) Encoder Grad: 0.2651  Decoder Grad: 0.1490  Encoder LR: 0.000049  Decoder LR: 0.000097
# Epoch: [7][8000/35984] Data 0.000 (0.000) Elapsed 102m 18s (remain 357m 48s) Loss: 0.0402(0.0609) Encoder Grad: 0.3629  Decoder Grad: 0.1560  Encoder LR: 0.000048  Decoder LR: 0.000097
# Epoch: [7][8100/35984] Data 0.000 (0.000) Elapsed 103m 35s (remain 356m 34s) Loss: 0.1042(0.0609) Encoder Grad: 0.3663  Decoder Grad: 0.1865  Encoder LR: 0.000048  Decoder LR: 0.000097
# Epoch: [7][8200/35984] Data 0.000 (0.000) Elapsed 104m 51s (remain 355m 15s) Loss: 0.0711(0.0608) Encoder Grad: 0.2967  Decoder Grad: 0.2132  Encoder LR: 0.000048  Decoder LR: 0.000097
# Epoch: [7][8300/35984] Data 0.000 (0.000) Elapsed 106m 9s (remain 354m 0s) Loss: 0.0375(0.0608) Encoder Grad: 0.3789  Decoder Grad: 0.1464  Encoder LR: 0.000048  Decoder LR: 0.000097
# Epoch: [7][8400/35984] Data 0.000 (0.000) Elapsed 107m 25s (remain 352m 44s) Loss: 0.0383(0.0607) Encoder Grad: 0.4172  Decoder Grad: 0.3184  Encoder LR: 0.000048  Decoder LR: 0.000097
# Epoch: [7][8500/35984] Data 0.000 (0.000) Elapsed 108m 41s (remain 351m 22s) Loss: 0.0665(0.0607) Encoder Grad: 0.3260  Decoder Grad: 0.1863  Encoder LR: 0.000048  Decoder LR: 0.000097
# Epoch: [7][8600/35984] Data 0.000 (0.000) Elapsed 109m 52s (remain 349m 48s) Loss: 0.0490(0.0606) Encoder Grad: 0.4923  Decoder Grad: 0.1355  Encoder LR: 0.000048  Decoder LR: 0.000097
# Epoch: [7][8700/35984] Data 0.000 (0.000) Elapsed 111m 8s (remain 348m 29s) Loss: 0.0538(0.0606) Encoder Grad: 0.2758  Decoder Grad: 0.1463  Encoder LR: 0.000048  Decoder LR: 0.000096
# Epoch: [7][8800/35984] Data 0.000 (0.000) Elapsed 112m 20s (remain 346m 57s) Loss: 0.0413(0.0605) Encoder Grad: 0.4210  Decoder Grad: 0.1689  Encoder LR: 0.000048  Decoder LR: 0.000096
# Epoch: [7][8900/35984] Data 0.000 (0.000) Elapsed 113m 31s (remain 345m 24s) Loss: 0.0596(0.0605) Encoder Grad: 0.6268  Decoder Grad: 0.1757  Encoder LR: 0.000048  Decoder LR: 0.000096
# Epoch: [7][9000/35984] Data 0.000 (0.000) Elapsed 114m 44s (remain 343m 57s) Loss: 0.0718(0.0604) Encoder Grad: 0.3274  Decoder Grad: 0.1708  Encoder LR: 0.000048  Decoder LR: 0.000096
# Epoch: [7][9100/35984] Data 0.000 (0.000) Elapsed 115m 56s (remain 342m 29s) Loss: 0.0846(0.0604) Encoder Grad: 0.3389  Decoder Grad: 0.1531  Encoder LR: 0.000048  Decoder LR: 0.000096
# Epoch: [7][9200/35984] Data 0.000 (0.000) Elapsed 117m 9s (remain 341m 2s) Loss: 0.0558(0.0603) Encoder Grad: 0.2235  Decoder Grad: 0.1551  Encoder LR: 0.000048  Decoder LR: 0.000096
# Epoch: [7][9300/35984] Data 0.000 (0.000) Elapsed 118m 21s (remain 339m 33s) Loss: 0.0671(0.0603) Encoder Grad: 1.0777  Decoder Grad: 0.1781  Encoder LR: 0.000048  Decoder LR: 0.000096
# Epoch: [7][9400/35984] Data 0.000 (0.000) Elapsed 119m 39s (remain 338m 20s) Loss: 0.0547(0.0603) Encoder Grad: 0.3391  Decoder Grad: 0.1695  Encoder LR: 0.000048  Decoder LR: 0.000096
# Epoch: [7][9500/35984] Data 0.000 (0.000) Elapsed 121m 0s (remain 337m 17s) Loss: 0.0667(0.0602) Encoder Grad: 0.5350  Decoder Grad: 0.1580  Encoder LR: 0.000048  Decoder LR: 0.000096
# Epoch: [7][9600/35984] Data 0.000 (0.000) Elapsed 122m 17s (remain 336m 1s) Loss: 0.0402(0.0602) Encoder Grad: 0.4954  Decoder Grad: 0.4809  Encoder LR: 0.000048  Decoder LR: 0.000096
# Epoch: [7][9700/35984] Data 0.000 (0.000) Elapsed 123m 30s (remain 334m 36s) Loss: 0.0731(0.0602) Encoder Grad: 0.2472  Decoder Grad: 0.1492  Encoder LR: 0.000048  Decoder LR: 0.000096
# Epoch: [7][9800/35984] Data 0.000 (0.000) Elapsed 124m 43s (remain 333m 10s) Loss: 0.0403(0.0602) Encoder Grad: 0.1955  Decoder Grad: 0.1473  Encoder LR: 0.000048  Decoder LR: 0.000095
# Epoch: [7][9900/35984] Data 0.000 (0.000) Elapsed 125m 56s (remain 331m 47s) Loss: 0.0325(0.0602) Encoder Grad: 0.2410  Decoder Grad: 0.1716  Encoder LR: 0.000048  Decoder LR: 0.000095
# Epoch: [7][10000/35984] Data 0.000 (0.000) Elapsed 127m 10s (remain 330m 25s) Loss: 0.0321(0.0601) Encoder Grad: 0.2706  Decoder Grad: 0.1355  Encoder LR: 0.000048  Decoder LR: 0.000095
# Epoch: [7][10100/35984] Data 0.000 (0.000) Elapsed 128m 27s (remain 329m 10s) Loss: 0.0775(0.0601) Encoder Grad: 0.2472  Decoder Grad: 0.1922  Encoder LR: 0.000048  Decoder LR: 0.000095
# Epoch: [7][10200/35984] Data 0.000 (0.000) Elapsed 129m 45s (remain 327m 56s) Loss: 0.0630(0.0600) Encoder Grad: 0.5909  Decoder Grad: 0.1970  Encoder LR: 0.000048  Decoder LR: 0.000095
# Epoch: [7][10300/35984] Data 0.000 (0.000) Elapsed 131m 3s (remain 326m 45s) Loss: 0.0481(0.0600) Encoder Grad: 0.3346  Decoder Grad: 0.1482  Encoder LR: 0.000048  Decoder LR: 0.000095
# Epoch: [7][10400/35984] Data 0.000 (0.000) Elapsed 132m 21s (remain 325m 33s) Loss: 0.0692(0.0599) Encoder Grad: 0.2183  Decoder Grad: 0.1555  Encoder LR: 0.000047  Decoder LR: 0.000095
# Epoch: [7][10500/35984] Data 0.000 (0.000) Elapsed 133m 37s (remain 324m 16s) Loss: 0.0469(0.0599) Encoder Grad: 0.3686  Decoder Grad: 0.1906  Encoder LR: 0.000047  Decoder LR: 0.000095
# Epoch: [7][10600/35984] Data 0.000 (0.000) Elapsed 134m 54s (remain 323m 1s) Loss: 0.0874(0.0599) Encoder Grad: 0.2717  Decoder Grad: 0.1740  Encoder LR: 0.000047  Decoder LR: 0.000095
# Epoch: [7][10700/35984] Data 0.000 (0.000) Elapsed 136m 11s (remain 321m 46s) Loss: 0.0773(0.0598) Encoder Grad: 0.3431  Decoder Grad: 0.1572  Encoder LR: 0.000047  Decoder LR: 0.000095
# Epoch: [7][10800/35984] Data 0.000 (0.000) Elapsed 137m 28s (remain 320m 30s) Loss: 0.0522(0.0598) Encoder Grad: 0.3221  Decoder Grad: 0.1572  Encoder LR: 0.000047  Decoder LR: 0.000095
# Epoch: [7][10900/35984] Data 0.000 (0.000) Elapsed 138m 45s (remain 319m 15s) Loss: 0.0372(0.0598) Encoder Grad: 0.1888  Decoder Grad: 0.1170  Encoder LR: 0.000047  Decoder LR: 0.000094
# Epoch: [7][11000/35984] Data 0.000 (0.000) Elapsed 140m 8s (remain 318m 14s) Loss: 0.0409(0.0598) Encoder Grad: 0.1984  Decoder Grad: 0.1284  Encoder LR: 0.000047  Decoder LR: 0.000094
# Epoch: [7][11100/35984] Data 0.000 (0.000) Elapsed 141m 32s (remain 317m 17s) Loss: 0.0237(0.0598) Encoder Grad: 0.1716  Decoder Grad: 0.1068  Encoder LR: 0.000047  Decoder LR: 0.000094
# Epoch: [7][11200/35984] Data 0.000 (0.000) Elapsed 142m 54s (remain 316m 12s) Loss: 0.0599(0.0598) Encoder Grad: 0.2190  Decoder Grad: 0.1402  Encoder LR: 0.000047  Decoder LR: 0.000094
# Epoch: [7][11300/35984] Data 0.000 (0.000) Elapsed 144m 18s (remain 315m 11s) Loss: 0.0447(0.0598) Encoder Grad: 0.1686  Decoder Grad: 0.1206  Encoder LR: 0.000047  Decoder LR: 0.000094
# Epoch: [7][11400/35984] Data 0.000 (0.000) Elapsed 145m 41s (remain 314m 8s) Loss: 0.0955(0.0597) Encoder Grad: 0.7501  Decoder Grad: 0.2264  Encoder LR: 0.000047  Decoder LR: 0.000094
# Epoch: [7][11500/35984] Data 0.000 (0.000) Elapsed 147m 4s (remain 313m 4s) Loss: 0.0528(0.0597) Encoder Grad: 0.2512  Decoder Grad: 0.1456  Encoder LR: 0.000047  Decoder LR: 0.000094
# Epoch: [7][11600/35984] Data 0.000 (0.000) Elapsed 148m 28s (remain 312m 4s) Loss: 0.0630(0.0597) Encoder Grad: 0.3293  Decoder Grad: 0.1556  Encoder LR: 0.000047  Decoder LR: 0.000094
# Epoch: [7][11700/35984] Data 0.000 (0.000) Elapsed 149m 50s (remain 310m 58s) Loss: 0.0598(0.0597) Encoder Grad: 0.3365  Decoder Grad: 0.2127  Encoder LR: 0.000047  Decoder LR: 0.000094
# Epoch: [7][11800/35984] Data 0.000 (0.000) Elapsed 151m 14s (remain 309m 56s) Loss: 0.0732(0.0596) Encoder Grad: 0.3064  Decoder Grad: 0.1586  Encoder LR: 0.000047  Decoder LR: 0.000094
# Epoch: [7][11900/35984] Data 0.000 (0.000) Elapsed 152m 37s (remain 308m 50s) Loss: 0.0414(0.0596) Encoder Grad: 0.1992  Decoder Grad: 0.1647  Encoder LR: 0.000047  Decoder LR: 0.000093
# Epoch: [7][12000/35984] Data 0.000 (0.000) Elapsed 153m 59s (remain 307m 45s) Loss: 0.0343(0.0596) Encoder Grad: 0.1720  Decoder Grad: 0.1362  Encoder LR: 0.000047  Decoder LR: 0.000093
# Epoch: [7][12100/35984] Data 0.000 (0.000) Elapsed 155m 23s (remain 306m 40s) Loss: 0.0635(0.0595) Encoder Grad: 0.6000  Decoder Grad: 0.2854  Encoder LR: 0.000047  Decoder LR: 0.000093
# Epoch: [7][12200/35984] Data 0.000 (0.000) Elapsed 156m 44s (remain 305m 32s) Loss: 0.0563(0.0595) Encoder Grad: 0.1820  Decoder Grad: 0.1234  Encoder LR: 0.000047  Decoder LR: 0.000093
# Epoch: [7][12300/35984] Data 0.000 (0.000) Elapsed 158m 7s (remain 304m 26s) Loss: 0.0345(0.0594) Encoder Grad: 0.1562  Decoder Grad: 0.1546  Encoder LR: 0.000046  Decoder LR: 0.000093
# Epoch: [7][12400/35984] Data 0.000 (0.000) Elapsed 159m 29s (remain 303m 18s) Loss: 0.0623(0.0594) Encoder Grad: 0.4770  Decoder Grad: 0.1936  Encoder LR: 0.000046  Decoder LR: 0.000093
# Epoch: [7][12500/35984] Data 0.000 (0.000) Elapsed 160m 51s (remain 302m 10s) Loss: 0.0513(0.0593) Encoder Grad: 0.6134  Decoder Grad: 0.1684  Encoder LR: 0.000046  Decoder LR: 0.000093
# Epoch: [7][12600/35984] Data 0.000 (0.000) Elapsed 162m 14s (remain 301m 4s) Loss: 0.0512(0.0593) Encoder Grad: 0.4208  Decoder Grad: 0.1817  Encoder LR: 0.000046  Decoder LR: 0.000093
# Epoch: [7][12700/35984] Data 0.000 (0.000) Elapsed 163m 37s (remain 299m 57s) Loss: 0.0686(0.0593) Encoder Grad: 0.3005  Decoder Grad: 0.1618  Encoder LR: 0.000046  Decoder LR: 0.000093
# Epoch: [7][12800/35984] Data 0.000 (0.000) Elapsed 165m 1s (remain 298m 52s) Loss: 0.0759(0.0592) Encoder Grad: 0.2165  Decoder Grad: 0.1458  Encoder LR: 0.000046  Decoder LR: 0.000092
# Epoch: [7][12900/35984] Data 0.000 (0.000) Elapsed 166m 23s (remain 297m 42s) Loss: 0.0369(0.0592) Encoder Grad: 0.1948  Decoder Grad: 0.1142  Encoder LR: 0.000046  Decoder LR: 0.000092
# Epoch: [7][13000/35984] Data 0.000 (0.000) Elapsed 167m 45s (remain 296m 34s) Loss: 0.0552(0.0592) Encoder Grad: 1.3183  Decoder Grad: 0.2909  Encoder LR: 0.000046  Decoder LR: 0.000092
# Epoch: [7][13100/35984] Data 0.000 (0.000) Elapsed 169m 9s (remain 295m 27s) Loss: 0.0471(0.0591) Encoder Grad: 0.5157  Decoder Grad: 0.2582  Encoder LR: 0.000046  Decoder LR: 0.000092
# Epoch: [7][13200/35984] Data 0.000 (0.000) Elapsed 170m 31s (remain 294m 17s) Loss: 0.0535(0.0591) Encoder Grad: 0.4284  Decoder Grad: 0.1552  Encoder LR: 0.000046  Decoder LR: 0.000092
# Epoch: [7][13300/35984] Data 0.000 (0.000) Elapsed 171m 54s (remain 293m 10s) Loss: 0.0404(0.0591) Encoder Grad: 0.1687  Decoder Grad: 0.1185  Encoder LR: 0.000046  Decoder LR: 0.000092
# Epoch: [7][13400/35984] Data 0.000 (0.000) Elapsed 173m 16s (remain 292m 0s) Loss: 0.0384(0.0590) Encoder Grad: 0.1770  Decoder Grad: 0.1277  Encoder LR: 0.000046  Decoder LR: 0.000092
# Epoch: [7][13500/35984] Data 0.000 (0.000) Elapsed 174m 39s (remain 290m 51s) Loss: 0.0333(0.0590) Encoder Grad: 0.2529  Decoder Grad: 0.1525  Encoder LR: 0.000046  Decoder LR: 0.000092
# Epoch: [7][13600/35984] Data 0.000 (0.000) Elapsed 176m 3s (remain 289m 44s) Loss: 0.0597(0.0590) Encoder Grad: 0.2268  Decoder Grad: 0.1519  Encoder LR: 0.000046  Decoder LR: 0.000091
# Epoch: [7][13700/35984] Data 0.000 (0.000) Elapsed 177m 25s (remain 288m 32s) Loss: 0.0240(0.0590) Encoder Grad: 0.2221  Decoder Grad: 0.1124  Encoder LR: 0.000046  Decoder LR: 0.000091
# Epoch: [7][13800/35984] Data 0.000 (0.000) Elapsed 178m 48s (remain 287m 24s) Loss: 0.0630(0.0590) Encoder Grad: 0.3564  Decoder Grad: 0.1670  Encoder LR: 0.000046  Decoder LR: 0.000091
# Epoch: [7][13900/35984] Data 0.000 (0.000) Elapsed 180m 10s (remain 286m 14s) Loss: 0.0601(0.0590) Encoder Grad: 0.2282  Decoder Grad: 0.1402  Encoder LR: 0.000046  Decoder LR: 0.000091
# Epoch: [7][14000/35984] Data 0.000 (0.000) Elapsed 181m 34s (remain 285m 4s) Loss: 0.0580(0.0589) Encoder Grad: 0.1806  Decoder Grad: 0.1670  Encoder LR: 0.000045  Decoder LR: 0.000091
# Epoch: [7][14100/35984] Data 0.000 (0.000) Elapsed 182m 57s (remain 283m 55s) Loss: 0.0417(0.0589) Encoder Grad: 0.1520  Decoder Grad: 0.1245  Encoder LR: 0.000045  Decoder LR: 0.000091
# Epoch: [7][14200/35984] Data 0.000 (0.000) Elapsed 184m 18s (remain 282m 42s) Loss: 0.0399(0.0589) Encoder Grad: 0.4872  Decoder Grad: 0.1764  Encoder LR: 0.000045  Decoder LR: 0.000091
# Epoch: [7][14300/35984] Data 0.000 (0.000) Elapsed 185m 42s (remain 281m 33s) Loss: 0.0413(0.0588) Encoder Grad: 0.2886  Decoder Grad: 0.1673  Encoder LR: 0.000045  Decoder LR: 0.000091
# Epoch: [7][14400/35984] Data 0.000 (0.000) Elapsed 187m 4s (remain 280m 22s) Loss: 0.0583(0.0588) Encoder Grad: 0.3652  Decoder Grad: 0.1901  Encoder LR: 0.000045  Decoder LR: 0.000090
# Epoch: [7][14500/35984] Data 0.000 (0.000) Elapsed 188m 26s (remain 279m 10s) Loss: 0.0422(0.0588) Encoder Grad: 0.4305  Decoder Grad: 0.1664  Encoder LR: 0.000045  Decoder LR: 0.000090
# Epoch: [7][14600/35984] Data 0.000 (0.000) Elapsed 189m 49s (remain 278m 0s) Loss: 0.0881(0.0587) Encoder Grad: 0.3904  Decoder Grad: 0.1676  Encoder LR: 0.000045  Decoder LR: 0.000090
# Epoch: [7][14700/35984] Data 0.000 (0.000) Elapsed 191m 11s (remain 276m 47s) Loss: 0.0579(0.0587) Encoder Grad: 0.3423  Decoder Grad: 0.2058  Encoder LR: 0.000045  Decoder LR: 0.000090
# Epoch: [7][14800/35984] Data 0.000 (0.000) Elapsed 192m 34s (remain 275m 37s) Loss: 0.0454(0.0587) Encoder Grad: 0.1776  Decoder Grad: 0.1604  Encoder LR: 0.000045  Decoder LR: 0.000090
# Epoch: [7][14900/35984] Data 0.000 (0.000) Elapsed 193m 56s (remain 274m 24s) Loss: 0.0647(0.0587) Encoder Grad: 0.3962  Decoder Grad: 0.1904  Encoder LR: 0.000045  Decoder LR: 0.000090
# Epoch: [7][15000/35984] Data 0.000 (0.000) Elapsed 195m 20s (remain 273m 14s) Loss: 0.0584(0.0587) Encoder Grad: 0.2669  Decoder Grad: 0.1621  Encoder LR: 0.000045  Decoder LR: 0.000090
# Epoch: [7][15100/35984] Data 0.000 (0.000) Elapsed 196m 43s (remain 272m 3s) Loss: 0.0463(0.0586) Encoder Grad: 0.2477  Decoder Grad: 0.1185  Encoder LR: 0.000045  Decoder LR: 0.000090
# Epoch: [7][15200/35984] Data 0.000 (0.000) Elapsed 198m 5s (remain 270m 49s) Loss: 0.0556(0.0586) Encoder Grad: 0.2071  Decoder Grad: 0.1251  Encoder LR: 0.000045  Decoder LR: 0.000089
# Epoch: [7][15300/35984] Data 0.000 (0.000) Elapsed 199m 29s (remain 269m 39s) Loss: 0.0293(0.0586) Encoder Grad: 0.1821  Decoder Grad: 0.0992  Encoder LR: 0.000045  Decoder LR: 0.000089
# Epoch: [7][15400/35984] Data 0.000 (0.000) Elapsed 200m 51s (remain 268m 26s) Loss: 0.0669(0.0586) Encoder Grad: 0.2814  Decoder Grad: 0.1821  Encoder LR: 0.000045  Decoder LR: 0.000089
# Epoch: [7][15500/35984] Data 0.000 (0.000) Elapsed 202m 14s (remain 267m 13s) Loss: 0.0780(0.0585) Encoder Grad: 0.2941  Decoder Grad: 0.1768  Encoder LR: 0.000045  Decoder LR: 0.000089
# Epoch: [7][15600/35984] Data 0.000 (0.000) Elapsed 203m 37s (remain 266m 1s) Loss: 0.0725(0.0585) Encoder Grad: 0.3076  Decoder Grad: 0.1903  Encoder LR: 0.000044  Decoder LR: 0.000089
# Epoch: [7][15700/35984] Data 0.000 (0.000) Elapsed 204m 58s (remain 264m 47s) Loss: 0.0661(0.0585) Encoder Grad: 0.4886  Decoder Grad: 0.1948  Encoder LR: 0.000044  Decoder LR: 0.000089
# Epoch: [7][15800/35984] Data 0.000 (0.000) Elapsed 206m 22s (remain 263m 35s) Loss: 0.0441(0.0584) Encoder Grad: 0.2511  Decoder Grad: 0.1539  Encoder LR: 0.000044  Decoder LR: 0.000089
# Epoch: [7][15900/35984] Data 0.000 (0.000) Elapsed 207m 43s (remain 262m 21s) Loss: 0.0489(0.0584) Encoder Grad: 0.1918  Decoder Grad: 0.1528  Encoder LR: 0.000044  Decoder LR: 0.000088
# Epoch: [7][16000/35984] Data 0.000 (0.000) Elapsed 209m 6s (remain 261m 8s) Loss: 0.0468(0.0584) Encoder Grad: 0.2534  Decoder Grad: 0.1319  Encoder LR: 0.000044  Decoder LR: 0.000088
# Epoch: [7][16100/35984] Data 0.000 (0.000) Elapsed 210m 29s (remain 259m 56s) Loss: 0.0573(0.0584) Encoder Grad: 0.5986  Decoder Grad: 0.1845  Encoder LR: 0.000044  Decoder LR: 0.000088
# Epoch: [7][16200/35984] Data 0.000 (0.000) Elapsed 211m 51s (remain 258m 41s) Loss: 0.0535(0.0583) Encoder Grad: 0.2527  Decoder Grad: 0.1328  Encoder LR: 0.000044  Decoder LR: 0.000088
# Epoch: [7][16300/35984] Data 0.000 (0.000) Elapsed 213m 14s (remain 257m 28s) Loss: 0.0386(0.0583) Encoder Grad: 0.2100  Decoder Grad: 0.1536  Encoder LR: 0.000044  Decoder LR: 0.000088
# Epoch: [7][16400/35984] Data 0.000 (0.000) Elapsed 214m 37s (remain 256m 16s) Loss: 0.1060(0.0582) Encoder Grad: 0.3604  Decoder Grad: 0.1685  Encoder LR: 0.000044  Decoder LR: 0.000088
# Epoch: [7][16500/35984] Data 0.000 (0.000) Elapsed 216m 0s (remain 255m 2s) Loss: 0.0352(0.0582) Encoder Grad: 0.2728  Decoder Grad: 0.1932  Encoder LR: 0.000044  Decoder LR: 0.000088
# Epoch: [7][16600/35984] Data 0.000 (0.000) Elapsed 217m 24s (remain 253m 50s) Loss: 0.0554(0.0582) Encoder Grad: 0.2992  Decoder Grad: 0.1479  Encoder LR: 0.000044  Decoder LR: 0.000087
# Epoch: [7][16700/35984] Data 0.000 (0.000) Elapsed 218m 45s (remain 252m 35s) Loss: 0.0609(0.0582) Encoder Grad: 0.2149  Decoder Grad: 0.1817  Encoder LR: 0.000044  Decoder LR: 0.000087
# Epoch: [7][16800/35984] Data 0.000 (0.000) Elapsed 220m 9s (remain 251m 22s) Loss: 0.0622(0.0581) Encoder Grad: 0.2234  Decoder Grad: 0.1407  Encoder LR: 0.000044  Decoder LR: 0.000087
# Epoch: [7][16900/35984] Data 0.000 (0.000) Elapsed 221m 31s (remain 250m 7s) Loss: 0.0576(0.0581) Encoder Grad: 0.2272  Decoder Grad: 0.1501  Encoder LR: 0.000044  Decoder LR: 0.000087
# Epoch: [7][17000/35984] Data 0.000 (0.000) Elapsed 222m 54s (remain 248m 53s) Loss: 0.0286(0.0581) Encoder Grad: 0.2297  Decoder Grad: 0.1423  Encoder LR: 0.000043  Decoder LR: 0.000087
# Epoch: [7][17100/35984] Data 0.000 (0.000) Elapsed 224m 17s (remain 247m 39s) Loss: 0.0647(0.0580) Encoder Grad: 0.3363  Decoder Grad: 0.1345  Encoder LR: 0.000043  Decoder LR: 0.000087
# Epoch: [7][17200/35984] Data 0.000 (0.000) Elapsed 225m 38s (remain 246m 23s) Loss: 0.0545(0.0580) Encoder Grad: 0.3285  Decoder Grad: 0.1497  Encoder LR: 0.000043  Decoder LR: 0.000087
# Epoch: [7][17300/35984] Data 0.000 (0.000) Elapsed 227m 1s (remain 245m 9s) Loss: 0.0773(0.0580) Encoder Grad: 0.2757  Decoder Grad: 0.1773  Encoder LR: 0.000043  Decoder LR: 0.000086
# Epoch: [7][17400/35984] Data 0.000 (0.000) Elapsed 228m 24s (remain 243m 55s) Loss: 0.0395(0.0580) Encoder Grad: 0.2602  Decoder Grad: 0.1960  Encoder LR: 0.000043  Decoder LR: 0.000086
# Epoch: [7][17500/35984] Data 0.000 (0.000) Elapsed 229m 47s (remain 242m 40s) Loss: 0.0295(0.0579) Encoder Grad: 0.1522  Decoder Grad: 0.1020  Encoder LR: 0.000043  Decoder LR: 0.000086
# Epoch: [7][17600/35984] Data 0.000 (0.000) Elapsed 231m 11s (remain 241m 27s) Loss: 0.0472(0.0579) Encoder Grad: 0.3120  Decoder Grad: 0.1484  Encoder LR: 0.000043  Decoder LR: 0.000086
# Epoch: [7][17700/35984] Data 0.000 (0.000) Elapsed 232m 32s (remain 240m 11s) Loss: 0.0605(0.0579) Encoder Grad: 0.2877  Decoder Grad: 0.1856  Encoder LR: 0.000043  Decoder LR: 0.000086
# Epoch: [7][17800/35984] Data 0.000 (0.000) Elapsed 233m 56s (remain 238m 57s) Loss: 0.0221(0.0579) Encoder Grad: 0.2544  Decoder Grad: 0.1037  Encoder LR: 0.000043  Decoder LR: 0.000086
# Epoch: [7][17900/35984] Data 0.000 (0.000) Elapsed 235m 13s (remain 237m 36s) Loss: 0.0398(0.0578) Encoder Grad: 0.2650  Decoder Grad: 0.1945  Encoder LR: 0.000043  Decoder LR: 0.000086
# Epoch: [7][18000/35984] Data 0.000 (0.000) Elapsed 236m 27s (remain 236m 13s) Loss: 0.0586(0.0578) Encoder Grad: 0.2940  Decoder Grad: 0.1826  Encoder LR: 0.000043  Decoder LR: 0.000085
# Epoch: [7][18100/35984] Data 0.000 (0.000) Elapsed 237m 40s (remain 234m 49s) Loss: 0.0554(0.0578) Encoder Grad: 0.3150  Decoder Grad: 0.1410  Encoder LR: 0.000043  Decoder LR: 0.000085
# Epoch: [7][18200/35984] Data 0.000 (0.000) Elapsed 238m 52s (remain 233m 23s) Loss: 0.0707(0.0577) Encoder Grad: 0.2438  Decoder Grad: 0.1774  Encoder LR: 0.000043  Decoder LR: 0.000085
# Epoch: [7][18300/35984] Data 0.000 (0.000) Elapsed 240m 4s (remain 231m 58s) Loss: 0.0556(0.0577) Encoder Grad: 0.2173  Decoder Grad: 0.1624  Encoder LR: 0.000042  Decoder LR: 0.000085
# Epoch: [7][18400/35984] Data 0.000 (0.000) Elapsed 241m 16s (remain 230m 32s) Loss: 0.0466(0.0577) Encoder Grad: 0.2712  Decoder Grad: 0.1344  Encoder LR: 0.000042  Decoder LR: 0.000085
# Epoch: [7][18500/35984] Data 0.000 (0.000) Elapsed 242m 26s (remain 229m 6s) Loss: 0.0616(0.0576) Encoder Grad: 0.4549  Decoder Grad: 0.1820  Encoder LR: 0.000042  Decoder LR: 0.000085
# Epoch: [7][18600/35984] Data 0.000 (0.000) Elapsed 243m 51s (remain 227m 53s) Loss: 0.0715(0.0576) Encoder Grad: 0.4378  Decoder Grad: 0.3171  Encoder LR: 0.000042  Decoder LR: 0.000084
# Epoch: [7][18700/35984] Data 0.000 (0.000) Elapsed 245m 14s (remain 226m 38s) Loss: 0.0588(0.0576) Encoder Grad: 0.3313  Decoder Grad: 0.2019  Encoder LR: 0.000042  Decoder LR: 0.000084
# Epoch: [7][18800/35984] Data 0.000 (0.000) Elapsed 246m 38s (remain 225m 25s) Loss: 0.0435(0.0576) Encoder Grad: 0.2408  Decoder Grad: 0.1586  Encoder LR: 0.000042  Decoder LR: 0.000084
# Epoch: [7][18900/35984] Data 0.000 (0.000) Elapsed 248m 2s (remain 224m 10s) Loss: 0.0391(0.0575) Encoder Grad: 0.3094  Decoder Grad: 0.1545  Encoder LR: 0.000042  Decoder LR: 0.000084
# Epoch: [7][19000/35984] Data 0.000 (0.000) Elapsed 249m 24s (remain 222m 55s) Loss: 0.0406(0.0575) Encoder Grad: 0.2127  Decoder Grad: 0.1193  Encoder LR: 0.000042  Decoder LR: 0.000084
# Epoch: [7][19100/35984] Data 0.000 (0.000) Elapsed 250m 44s (remain 221m 37s) Loss: 0.0414(0.0575) Encoder Grad: 0.2731  Decoder Grad: 0.1429  Encoder LR: 0.000042  Decoder LR: 0.000084
# Epoch: [7][19200/35984] Data 0.000 (0.000) Elapsed 251m 54s (remain 220m 11s) Loss: 0.0552(0.0575) Encoder Grad: 0.5788  Decoder Grad: 0.1663  Encoder LR: 0.000042  Decoder LR: 0.000083
# Epoch: [7][19300/35984] Data 0.000 (0.000) Elapsed 253m 3s (remain 218m 44s) Loss: 0.0519(0.0574) Encoder Grad: 0.3749  Decoder Grad: 0.2358  Encoder LR: 0.000042  Decoder LR: 0.000083
# Epoch: [7][19400/35984] Data 0.000 (0.000) Elapsed 254m 13s (remain 217m 17s) Loss: 0.1123(0.0574) Encoder Grad: 0.9054  Decoder Grad: 0.2126  Encoder LR: 0.000042  Decoder LR: 0.000083
# Epoch: [7][19500/35984] Data 0.000 (0.000) Elapsed 255m 22s (remain 215m 50s) Loss: 0.1032(0.0574) Encoder Grad: 0.3480  Decoder Grad: 0.1855  Encoder LR: 0.000041  Decoder LR: 0.000083
# Epoch: [7][19600/35984] Data 0.000 (0.000) Elapsed 256m 31s (remain 214m 24s) Loss: 0.0491(0.0574) Encoder Grad: 0.2749  Decoder Grad: 0.1077  Encoder LR: 0.000041  Decoder LR: 0.000083
# Epoch: [7][19700/35984] Data 0.000 (0.000) Elapsed 257m 39s (remain 212m 57s) Loss: 0.0486(0.0573) Encoder Grad: 0.3011  Decoder Grad: 0.1246  Encoder LR: 0.000041  Decoder LR: 0.000083
# Epoch: [7][19800/35984] Data 0.000 (0.000) Elapsed 258m 48s (remain 211m 31s) Loss: 0.0805(0.0573) Encoder Grad: 0.2789  Decoder Grad: 0.1876  Encoder LR: 0.000041  Decoder LR: 0.000082
# Epoch: [7][19900/35984] Data 0.000 (0.000) Elapsed 259m 58s (remain 210m 5s) Loss: 0.0728(0.0573) Encoder Grad: 0.3025  Decoder Grad: 0.1803  Encoder LR: 0.000041  Decoder LR: 0.000082
# Epoch: [7][20000/35984] Data 0.000 (0.000) Elapsed 261m 9s (remain 208m 41s) Loss: 0.0486(0.0573) Encoder Grad: 0.2378  Decoder Grad: 0.1387  Encoder LR: 0.000041  Decoder LR: 0.000082
# Epoch: [7][20100/35984] Data 0.000 (0.000) Elapsed 262m 17s (remain 207m 15s) Loss: 0.0501(0.0572) Encoder Grad: 0.2292  Decoder Grad: 0.1123  Encoder LR: 0.000041  Decoder LR: 0.000082
# Epoch: [7][20200/35984] Data 0.000 (0.000) Elapsed 263m 26s (remain 205m 49s) Loss: 0.0404(0.0572) Encoder Grad: 0.1888  Decoder Grad: 0.1301  Encoder LR: 0.000041  Decoder LR: 0.000082
# Epoch: [7][20300/35984] Data 0.000 (0.000) Elapsed 264m 35s (remain 204m 24s) Loss: 0.0328(0.0572) Encoder Grad: 0.1631  Decoder Grad: 0.1217  Encoder LR: 0.000041  Decoder LR: 0.000082
# Epoch: [7][20400/35984] Data 0.000 (0.000) Elapsed 265m 44s (remain 202m 58s) Loss: 0.0422(0.0572) Encoder Grad: 0.1277  Decoder Grad: 0.1233  Encoder LR: 0.000041  Decoder LR: 0.000081
# Epoch: [7][20500/35984] Data 0.000 (0.000) Elapsed 266m 54s (remain 201m 34s) Loss: 0.0407(0.0571) Encoder Grad: 0.2305  Decoder Grad: 0.1465  Encoder LR: 0.000041  Decoder LR: 0.000081
# Epoch: [7][20600/35984] Data 0.000 (0.000) Elapsed 268m 2s (remain 200m 9s) Loss: 0.0593(0.0571) Encoder Grad: 0.2666  Decoder Grad: 0.1491  Encoder LR: 0.000041  Decoder LR: 0.000081
# Epoch: [7][20700/35984] Data 0.000 (0.000) Elapsed 269m 13s (remain 198m 45s) Loss: 0.0649(0.0571) Encoder Grad: 0.2527  Decoder Grad: 0.1504  Encoder LR: 0.000040  Decoder LR: 0.000081
# Epoch: [7][20800/35984] Data 0.000 (0.000) Elapsed 270m 22s (remain 197m 20s) Loss: 0.0496(0.0571) Encoder Grad: 0.3236  Decoder Grad: 0.2135  Encoder LR: 0.000040  Decoder LR: 0.000081
# Epoch: [7][20900/35984] Data 0.000 (0.000) Elapsed 271m 31s (remain 195m 56s) Loss: 0.1187(0.0571) Encoder Grad: 0.3988  Decoder Grad: 0.1757  Encoder LR: 0.000040  Decoder LR: 0.000081
# Epoch: [7][21000/35984] Data 0.000 (0.000) Elapsed 272m 40s (remain 194m 32s) Loss: 0.0380(0.0570) Encoder Grad: 0.1777  Decoder Grad: 0.1398  Encoder LR: 0.000040  Decoder LR: 0.000080
# Epoch: [7][21100/35984] Data 0.000 (0.000) Elapsed 273m 49s (remain 193m 8s) Loss: 0.0474(0.0570) Encoder Grad: 0.2416  Decoder Grad: 0.1357  Encoder LR: 0.000040  Decoder LR: 0.000080
# Epoch: [7][21200/35984] Data 0.000 (0.000) Elapsed 275m 0s (remain 191m 45s) Loss: 0.0525(0.0570) Encoder Grad: 0.2892  Decoder Grad: 0.2134  Encoder LR: 0.000040  Decoder LR: 0.000080
# Epoch: [7][21300/35984] Data 0.000 (0.000) Elapsed 276m 11s (remain 190m 23s) Loss: 0.0906(0.0569) Encoder Grad: 0.3062  Decoder Grad: 0.2190  Encoder LR: 0.000040  Decoder LR: 0.000080
# Epoch: [7][21400/35984] Data 0.000 (0.000) Elapsed 277m 21s (remain 189m 0s) Loss: 0.0468(0.0569) Encoder Grad: 0.2994  Decoder Grad: 0.1564  Encoder LR: 0.000040  Decoder LR: 0.000080
# Epoch: [7][21500/35984] Data 0.000 (0.000) Elapsed 278m 33s (remain 187m 38s) Loss: 0.0245(0.0569) Encoder Grad: 0.1818  Decoder Grad: 0.1157  Encoder LR: 0.000040  Decoder LR: 0.000080
# Epoch: [7][21600/35984] Data 0.000 (0.000) Elapsed 279m 43s (remain 186m 15s) Loss: 0.0510(0.0569) Encoder Grad: 0.2625  Decoder Grad: 0.1174  Encoder LR: 0.000040  Decoder LR: 0.000079
# Epoch: [7][21700/35984] Data 0.000 (0.000) Elapsed 280m 54s (remain 184m 53s) Loss: 0.0413(0.0569) Encoder Grad: 0.2892  Decoder Grad: 0.1539  Encoder LR: 0.000040  Decoder LR: 0.000079
# Epoch: [7][21800/35984] Data 0.000 (0.000) Elapsed 282m 5s (remain 183m 30s) Loss: 0.0361(0.0568) Encoder Grad: 0.4620  Decoder Grad: 0.1387  Encoder LR: 0.000040  Decoder LR: 0.000079
# Epoch: [7][21900/35984] Data 0.000 (0.000) Elapsed 283m 15s (remain 182m 8s) Loss: 0.0716(0.0568) Encoder Grad: 0.3350  Decoder Grad: 0.1577  Encoder LR: 0.000039  Decoder LR: 0.000079
# Epoch: [7][22000/35984] Data 0.000 (0.000) Elapsed 284m 25s (remain 180m 46s) Loss: 0.0756(0.0568) Encoder Grad: 0.2331  Decoder Grad: 0.1582  Encoder LR: 0.000039  Decoder LR: 0.000079
# Epoch: [7][22100/35984] Data 0.000 (0.000) Elapsed 285m 35s (remain 179m 23s) Loss: 0.0246(0.0567) Encoder Grad: 0.2370  Decoder Grad: 0.1012  Encoder LR: 0.000039  Decoder LR: 0.000079
# Epoch: [7][22200/35984] Data 0.000 (0.000) Elapsed 286m 46s (remain 178m 2s) Loss: 0.0264(0.0567) Encoder Grad: 0.0949  Decoder Grad: 0.0965  Encoder LR: 0.000039  Decoder LR: 0.000078
# Epoch: [7][22300/35984] Data 0.000 (0.000) Elapsed 287m 57s (remain 176m 40s) Loss: 0.0590(0.0567) Encoder Grad: 0.2795  Decoder Grad: 0.1519  Encoder LR: 0.000039  Decoder LR: 0.000078
# Epoch: [7][22400/35984] Data 0.000 (0.000) Elapsed 289m 7s (remain 175m 18s) Loss: 0.0477(0.0567) Encoder Grad: 0.3793  Decoder Grad: 0.1666  Encoder LR: 0.000039  Decoder LR: 0.000078
# Epoch: [7][22500/35984] Data 0.000 (0.000) Elapsed 290m 18s (remain 173m 57s) Loss: 0.0421(0.0567) Encoder Grad: 0.2691  Decoder Grad: 0.1930  Encoder LR: 0.000039  Decoder LR: 0.000078
# Epoch: [7][22600/35984] Data 0.000 (0.000) Elapsed 291m 28s (remain 172m 35s) Loss: 0.0242(0.0566) Encoder Grad: 0.2551  Decoder Grad: 0.1178  Encoder LR: 0.000039  Decoder LR: 0.000078
# Epoch: [7][22700/35984] Data 0.000 (0.000) Elapsed 292m 39s (remain 171m 14s) Loss: 0.0466(0.0566) Encoder Grad: 0.2678  Decoder Grad: 0.1290  Encoder LR: 0.000039  Decoder LR: 0.000077
# Epoch: [7][22800/35984] Data 0.000 (0.000) Elapsed 293m 49s (remain 169m 53s) Loss: 0.0571(0.0566) Encoder Grad: 0.2307  Decoder Grad: 0.1320  Encoder LR: 0.000039  Decoder LR: 0.000077
# Epoch: [7][22900/35984] Data 0.000 (0.000) Elapsed 295m 0s (remain 168m 32s) Loss: 0.0448(0.0566) Encoder Grad: 0.2700  Decoder Grad: 0.1861  Encoder LR: 0.000039  Decoder LR: 0.000077
# Epoch: [7][23000/35984] Data 0.000 (0.000) Elapsed 296m 11s (remain 167m 10s) Loss: 0.0629(0.0565) Encoder Grad: 0.3465  Decoder Grad: 0.1515  Encoder LR: 0.000038  Decoder LR: 0.000077
# Epoch: [7][23100/35984] Data 0.000 (0.000) Elapsed 297m 22s (remain 165m 50s) Loss: 0.0192(0.0565) Encoder Grad: 0.1760  Decoder Grad: 0.1182  Encoder LR: 0.000038  Decoder LR: 0.000077
# Epoch: [7][23200/35984] Data 0.000 (0.000) Elapsed 298m 32s (remain 164m 29s) Loss: 0.0793(0.0565) Encoder Grad: 0.3492  Decoder Grad: 0.1747  Encoder LR: 0.000038  Decoder LR: 0.000076
# Epoch: [7][23300/35984] Data 0.000 (0.000) Elapsed 299m 42s (remain 163m 7s) Loss: 0.0726(0.0565) Encoder Grad: 0.2576  Decoder Grad: 0.1983  Encoder LR: 0.000038  Decoder LR: 0.000076
# Epoch: [7][23400/35984] Data 0.000 (0.000) Elapsed 300m 51s (remain 161m 46s) Loss: 0.0508(0.0565) Encoder Grad: 0.2334  Decoder Grad: 0.1752  Encoder LR: 0.000038  Decoder LR: 0.000076
# Epoch: [7][23500/35984] Data 0.000 (0.000) Elapsed 302m 0s (remain 160m 25s) Loss: 0.0419(0.0565) Encoder Grad: 0.4880  Decoder Grad: 0.1758  Encoder LR: 0.000038  Decoder LR: 0.000076
# Epoch: [7][23600/35984] Data 0.000 (0.000) Elapsed 303m 9s (remain 159m 3s) Loss: 0.0465(0.0564) Encoder Grad: 0.1798  Decoder Grad: 0.1501  Encoder LR: 0.000038  Decoder LR: 0.000076
# Epoch: [7][23700/35984] Data 0.000 (0.000) Elapsed 304m 18s (remain 157m 42s) Loss: 0.0619(0.0564) Encoder Grad: 0.6730  Decoder Grad: 0.1753  Encoder LR: 0.000038  Decoder LR: 0.000076
# Epoch: [7][23800/35984] Data 0.000 (0.000) Elapsed 305m 27s (remain 156m 21s) Loss: 0.0379(0.0564) Encoder Grad: 0.5864  Decoder Grad: 0.1694  Encoder LR: 0.000038  Decoder LR: 0.000075
# Epoch: [7][23900/35984] Data 0.000 (0.000) Elapsed 306m 36s (remain 155m 0s) Loss: 0.0450(0.0564) Encoder Grad: 0.4020  Decoder Grad: 0.2092  Encoder LR: 0.000038  Decoder LR: 0.000075
# Epoch: [7][24000/35984] Data 0.000 (0.000) Elapsed 307m 48s (remain 153m 40s) Loss: 0.0347(0.0563) Encoder Grad: 0.1924  Decoder Grad: 0.1404  Encoder LR: 0.000038  Decoder LR: 0.000075
# Epoch: [7][24100/35984] Data 0.000 (0.000) Elapsed 309m 4s (remain 152m 23s) Loss: 0.0612(0.0563) Encoder Grad: 0.2893  Decoder Grad: 0.1713  Encoder LR: 0.000037  Decoder LR: 0.000075
# Epoch: [7][24200/35984] Data 0.000 (0.000) Elapsed 310m 21s (remain 151m 6s) Loss: 0.0316(0.0563) Encoder Grad: 0.2109  Decoder Grad: 0.1398  Encoder LR: 0.000037  Decoder LR: 0.000075
# Epoch: [7][24300/35984] Data 0.000 (0.000) Elapsed 311m 36s (remain 149m 48s) Loss: 0.0264(0.0563) Encoder Grad: 0.1786  Decoder Grad: 0.1060  Encoder LR: 0.000037  Decoder LR: 0.000074
# Epoch: [7][24400/35984] Data 0.000 (0.000) Elapsed 312m 49s (remain 148m 29s) Loss: 0.0311(0.0562) Encoder Grad: 0.2894  Decoder Grad: 0.1270  Encoder LR: 0.000037  Decoder LR: 0.000074
# Epoch: [7][24500/35984] Data 0.000 (0.000) Elapsed 314m 5s (remain 147m 12s) Loss: 0.0842(0.0562) Encoder Grad: 0.3549  Decoder Grad: 0.1747  Encoder LR: 0.000037  Decoder LR: 0.000074
# Epoch: [7][24600/35984] Data 0.000 (0.000) Elapsed 315m 24s (remain 145m 56s) Loss: 0.0241(0.0562) Encoder Grad: 0.1417  Decoder Grad: 0.1075  Encoder LR: 0.000037  Decoder LR: 0.000074
# Epoch: [7][24700/35984] Data 0.000 (0.000) Elapsed 316m 47s (remain 144m 42s) Loss: 0.0336(0.0562) Encoder Grad: 0.2094  Decoder Grad: 0.1218  Encoder LR: 0.000037  Decoder LR: 0.000074
# Epoch: [7][24800/35984] Data 0.000 (0.000) Elapsed 318m 6s (remain 143m 26s) Loss: 0.0655(0.0561) Encoder Grad: 0.3483  Decoder Grad: 0.1628  Encoder LR: 0.000037  Decoder LR: 0.000073
# Epoch: [7][24900/35984] Data 0.000 (0.000) Elapsed 319m 23s (remain 142m 9s) Loss: 0.0594(0.0561) Encoder Grad: 1.1060  Decoder Grad: 0.1841  Encoder LR: 0.000037  Decoder LR: 0.000073
# Epoch: [7][25000/35984] Data 0.000 (0.000) Elapsed 320m 39s (remain 140m 52s) Loss: 0.0407(0.0561) Encoder Grad: 0.4087  Decoder Grad: 0.1771  Encoder LR: 0.000037  Decoder LR: 0.000073
# Epoch: [7][25100/35984] Data 0.000 (0.000) Elapsed 321m 55s (remain 139m 34s) Loss: 0.0401(0.0561) Encoder Grad: 0.2681  Decoder Grad: 0.1429  Encoder LR: 0.000036  Decoder LR: 0.000073
# Epoch: [7][25200/35984] Data 0.000 (0.000) Elapsed 323m 9s (remain 138m 16s) Loss: 0.0867(0.0560) Encoder Grad: 0.3727  Decoder Grad: 0.1615  Encoder LR: 0.000036  Decoder LR: 0.000073
# Epoch: [7][25300/35984] Data 0.000 (0.000) Elapsed 324m 25s (remain 136m 58s) Loss: 0.0407(0.0560) Encoder Grad: 0.1275  Decoder Grad: 0.1248  Encoder LR: 0.000036  Decoder LR: 0.000073
# Epoch: [7][25400/35984] Data 0.000 (0.000) Elapsed 325m 40s (remain 135m 41s) Loss: 0.0565(0.0560) Encoder Grad: 0.3310  Decoder Grad: 0.1464  Encoder LR: 0.000036  Decoder LR: 0.000072
# Epoch: [7][25500/35984] Data 0.000 (0.000) Elapsed 326m 55s (remain 134m 23s) Loss: 0.0326(0.0560) Encoder Grad: 0.2499  Decoder Grad: 0.1820  Encoder LR: 0.000036  Decoder LR: 0.000072
# ...
# Epoch: [8][29000/35984] Data 0.000 (0.000) Elapsed 362m 40s (remain 87m 19s) Loss: 0.0580(0.0408) Encoder Grad: 0.3534  Decoder Grad: 0.1636  Encoder LR: 0.000001  Decoder LR: 0.000002
# Epoch: [8][29100/35984] Data 0.000 (0.000) Elapsed 363m 53s (remain 86m 4s) Loss: 0.0182(0.0408) Encoder Grad: 0.1129  Decoder Grad: 0.1170  Encoder LR: 0.000001  Decoder LR: 0.000002
# Epoch: [8][29200/35984] Data 0.000 (0.000) Elapsed 365m 6s (remain 84m 48s) Loss: 0.0475(0.0407) Encoder Grad: 0.2761  Decoder Grad: 0.1145  Encoder LR: 0.000001  Decoder LR: 0.000002
# Epoch: [8][29300/35984] Data 0.000 (0.000) Elapsed 366m 19s (remain 83m 33s) Loss: 0.0552(0.0407) Encoder Grad: 0.2324  Decoder Grad: 0.1259  Encoder LR: 0.000001  Decoder LR: 0.000002
# Epoch: [8][29400/35984] Data 0.000 (0.000) Elapsed 367m 32s (remain 82m 17s) Loss: 0.0604(0.0407) Encoder Grad: 0.1362  Decoder Grad: 0.1277  Encoder LR: 0.000001  Decoder LR: 0.000002
# Epoch: [8][29500/35984] Data 0.000 (0.000) Elapsed 368m 46s (remain 81m 2s) Loss: 0.0420(0.0407) Encoder Grad: 0.2694  Decoder Grad: 0.1813  Encoder LR: 0.000001  Decoder LR: 0.000002
# Epoch: [8][29600/35984] Data 0.000 (0.000) Elapsed 369m 59s (remain 79m 46s) Loss: 0.0190(0.0407) Encoder Grad: 0.1173  Decoder Grad: 0.0923  Encoder LR: 0.000001  Decoder LR: 0.000002
# Epoch: [8][29700/35984] Data 0.000 (0.000) Elapsed 371m 12s (remain 78m 31s) Loss: 0.0627(0.0407) Encoder Grad: 0.2384  Decoder Grad: 0.1763  Encoder LR: 0.000001  Decoder LR: 0.000002
# Epoch: [8][29800/35984] Data 0.000 (0.000) Elapsed 372m 25s (remain 77m 16s) Loss: 0.0212(0.0407) Encoder Grad: 0.1398  Decoder Grad: 0.1315  Encoder LR: 0.000001  Decoder LR: 0.000002
# Epoch: [8][29900/35984] Data 0.000 (0.000) Elapsed 373m 38s (remain 76m 0s) Loss: 0.0208(0.0407) Encoder Grad: 0.1506  Decoder Grad: 0.1320  Encoder LR: 0.000001  Decoder LR: 0.000002
# Epoch: [8][30000/35984] Data 0.000 (0.000) Elapsed 374m 51s (remain 74m 45s) Loss: 0.0251(0.0406) Encoder Grad: 0.2459  Decoder Grad: 0.1079  Encoder LR: 0.000001  Decoder LR: 0.000002
# Epoch: [8][30100/35984] Data 0.000 (0.000) Elapsed 376m 4s (remain 73m 30s) Loss: 0.0291(0.0406) Encoder Grad: 0.6513  Decoder Grad: 0.1786  Encoder LR: 0.000001  Decoder LR: 0.000002
# Epoch: [8][30200/35984] Data 0.000 (0.000) Elapsed 377m 18s (remain 72m 14s) Loss: 0.0235(0.0406) Encoder Grad: 0.1384  Decoder Grad: 0.0938  Encoder LR: 0.000001  Decoder LR: 0.000002
# Epoch: [8][30300/35984] Data 0.000 (0.000) Elapsed 378m 31s (remain 70m 59s) Loss: 0.0403(0.0406) Encoder Grad: 0.2971  Decoder Grad: 0.1994  Encoder LR: 0.000001  Decoder LR: 0.000002
# Epoch: [8][30400/35984] Data 0.000 (0.000) Elapsed 379m 44s (remain 69m 44s) Loss: 0.0120(0.0406) Encoder Grad: 0.0777  Decoder Grad: 0.0727  Encoder LR: 0.000001  Decoder LR: 0.000002
# Epoch: [8][30500/35984] Data 0.000 (0.000) Elapsed 380m 58s (remain 68m 29s) Loss: 0.0551(0.0406) Encoder Grad: 0.2891  Decoder Grad: 0.1273  Encoder LR: 0.000001  Decoder LR: 0.000002
# Epoch: [8][30600/35984] Data 0.000 (0.000) Elapsed 382m 10s (remain 67m 13s) Loss: 0.0549(0.0406) Encoder Grad: 0.2352  Decoder Grad: 0.1406  Encoder LR: 0.000001  Decoder LR: 0.000001
# Epoch: [8][30700/35984] Data 0.000 (0.000) Elapsed 383m 24s (remain 65m 58s) Loss: 0.0385(0.0406) Encoder Grad: 0.1830  Decoder Grad: 0.1188  Encoder LR: 0.000001  Decoder LR: 0.000001
# Epoch: [8][30800/35984] Data 0.000 (0.000) Elapsed 384m 37s (remain 64m 43s) Loss: 0.0340(0.0406) Encoder Grad: 0.2933  Decoder Grad: 0.1344  Encoder LR: 0.000001  Decoder LR: 0.000001
# Epoch: [8][30900/35984] Data 0.000 (0.000) Elapsed 385m 51s (remain 63m 28s) Loss: 0.0220(0.0406) Encoder Grad: 0.3615  Decoder Grad: 0.1044  Encoder LR: 0.000001  Decoder LR: 0.000001
# Epoch: [8][31000/35984] Data 0.000 (0.000) Elapsed 387m 5s (remain 62m 13s) Loss: 0.0298(0.0406) Encoder Grad: 0.1974  Decoder Grad: 0.2131  Encoder LR: 0.000001  Decoder LR: 0.000001
# Epoch: [8][31100/35984] Data 0.000 (0.000) Elapsed 388m 19s (remain 60m 58s) Loss: 0.0155(0.0406) Encoder Grad: 0.1624  Decoder Grad: 0.1022  Encoder LR: 0.000001  Decoder LR: 0.000001
# Epoch: [8][31200/35984] Data 0.000 (0.000) Elapsed 389m 33s (remain 59m 43s) Loss: 0.0388(0.0406) Encoder Grad: 0.2351  Decoder Grad: 0.1493  Encoder LR: 0.000001  Decoder LR: 0.000001
# Epoch: [8][31300/35984] Data 0.000 (0.000) Elapsed 390m 46s (remain 58m 27s) Loss: 0.0459(0.0406) Encoder Grad: 0.2822  Decoder Grad: 0.1158  Encoder LR: 0.000001  Decoder LR: 0.000001
# Epoch: [8][31400/35984] Data 0.000 (0.000) Elapsed 391m 59s (remain 57m 12s) Loss: 0.0531(0.0406) Encoder Grad: 0.2128  Decoder Grad: 0.1471  Encoder LR: 0.000001  Decoder LR: 0.000001
# Epoch: [8][31500/35984] Data 0.000 (0.000) Elapsed 393m 12s (remain 55m 57s) Loss: 0.0234(0.0405) Encoder Grad: 0.2384  Decoder Grad: 0.1165  Encoder LR: 0.000001  Decoder LR: 0.000001
# Epoch: [8][31600/35984] Data 0.000 (0.000) Elapsed 394m 25s (remain 54m 42s) Loss: 0.0596(0.0405) Encoder Grad: 0.2573  Decoder Grad: 0.1204  Encoder LR: 0.000001  Decoder LR: 0.000001
# Epoch: [8][31700/35984] Data 0.000 (0.000) Elapsed 395m 38s (remain 53m 27s) Loss: 0.0818(0.0405) Encoder Grad: 0.4640  Decoder Grad: 0.2942  Encoder LR: 0.000001  Decoder LR: 0.000001
# Epoch: [8][31800/35984] Data 0.000 (0.000) Elapsed 396m 51s (remain 52m 12s) Loss: 0.0285(0.0405) Encoder Grad: 0.1265  Decoder Grad: 0.1063  Encoder LR: 0.000001  Decoder LR: 0.000001
# Epoch: [8][31900/35984] Data 0.000 (0.000) Elapsed 398m 4s (remain 50m 56s) Loss: 0.0238(0.0405) Encoder Grad: 0.3712  Decoder Grad: 0.1245  Encoder LR: 0.000000  Decoder LR: 0.000001
# Epoch: [8][32000/35984] Data 0.000 (0.000) Elapsed 399m 17s (remain 49m 41s) Loss: 0.0315(0.0405) Encoder Grad: 0.1656  Decoder Grad: 0.1198  Encoder LR: 0.000000  Decoder LR: 0.000001
# Epoch: [8][32100/35984] Data 0.000 (0.000) Elapsed 400m 30s (remain 48m 26s) Loss: 0.0283(0.0405) Encoder Grad: 0.2038  Decoder Grad: 0.1341  Encoder LR: 0.000000  Decoder LR: 0.000001
# Epoch: [8][32200/35984] Data 0.000 (0.000) Elapsed 401m 44s (remain 47m 11s) Loss: 0.0240(0.0405) Encoder Grad: 0.1132  Decoder Grad: 0.0907  Encoder LR: 0.000000  Decoder LR: 0.000001
# Epoch: [8][32300/35984] Data 0.000 (0.000) Elapsed 402m 57s (remain 45m 56s) Loss: 0.0456(0.0405) Encoder Grad: 0.2203  Decoder Grad: 0.1352  Encoder LR: 0.000000  Decoder LR: 0.000001
# Epoch: [8][32400/35984] Data 0.000 (0.000) Elapsed 404m 10s (remain 44m 41s) Loss: 0.0269(0.0404) Encoder Grad: 0.5669  Decoder Grad: 0.1082  Encoder LR: 0.000000  Decoder LR: 0.000001
# Epoch: [8][32500/35984] Data 0.000 (0.000) Elapsed 405m 23s (remain 43m 26s) Loss: 0.0224(0.0404) Encoder Grad: 0.2482  Decoder Grad: 0.1860  Encoder LR: 0.000000  Decoder LR: 0.000001
# Epoch: [8][32600/35984] Data 0.000 (0.000) Elapsed 406m 36s (remain 42m 11s) Loss: 0.0566(0.0404) Encoder Grad: 0.4506  Decoder Grad: 0.3295  Encoder LR: 0.000000  Decoder LR: 0.000001
# Epoch: [8][32700/35984] Data 0.000 (0.000) Elapsed 407m 49s (remain 40m 56s) Loss: 0.0409(0.0404) Encoder Grad: 0.3030  Decoder Grad: 0.2177  Encoder LR: 0.000000  Decoder LR: 0.000001
# Epoch: [8][32800/35984] Data 0.000 (0.000) Elapsed 409m 3s (remain 39m 41s) Loss: 0.0566(0.0404) Encoder Grad: 0.2647  Decoder Grad: 0.1360  Encoder LR: 0.000000  Decoder LR: 0.000001
# Epoch: [8][32900/35984] Data 0.000 (0.000) Elapsed 410m 16s (remain 38m 26s) Loss: 0.0202(0.0404) Encoder Grad: 0.1935  Decoder Grad: 0.1567  Encoder LR: 0.000000  Decoder LR: 0.000001
# Epoch: [8][33000/35984] Data 0.000 (0.000) Elapsed 411m 29s (remain 37m 11s) Loss: 0.0311(0.0404) Encoder Grad: 0.8368  Decoder Grad: 0.2392  Encoder LR: 0.000000  Decoder LR: 0.000001
# Epoch: [8][33100/35984] Data 0.000 (0.000) Elapsed 412m 42s (remain 35m 56s) Loss: 0.0240(0.0404) Encoder Grad: 0.1617  Decoder Grad: 0.1302  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][33200/35984] Data 0.000 (0.000) Elapsed 413m 56s (remain 34m 41s) Loss: 0.0290(0.0404) Encoder Grad: 0.1680  Decoder Grad: 0.0932  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][33300/35984] Data 0.000 (0.000) Elapsed 415m 9s (remain 33m 26s) Loss: 0.0671(0.0404) Encoder Grad: 0.2700  Decoder Grad: 0.1864  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][33400/35984] Data 0.000 (0.000) Elapsed 416m 23s (remain 32m 12s) Loss: 0.0384(0.0404) Encoder Grad: 0.5951  Decoder Grad: 0.1333  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][33500/35984] Data 0.000 (0.000) Elapsed 417m 35s (remain 30m 57s) Loss: 0.0365(0.0404) Encoder Grad: 0.1497  Decoder Grad: 0.1117  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][33600/35984] Data 0.000 (0.000) Elapsed 418m 49s (remain 29m 42s) Loss: 0.0457(0.0404) Encoder Grad: 0.2239  Decoder Grad: 0.1655  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][33700/35984] Data 0.000 (0.000) Elapsed 420m 2s (remain 28m 27s) Loss: 0.0447(0.0404) Encoder Grad: 0.2129  Decoder Grad: 0.1306  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][33800/35984] Data 0.000 (0.000) Elapsed 421m 16s (remain 27m 12s) Loss: 0.0407(0.0404) Encoder Grad: 0.3366  Decoder Grad: 0.1779  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][33900/35984] Data 0.000 (0.000) Elapsed 422m 29s (remain 25m 57s) Loss: 0.0478(0.0403) Encoder Grad: 0.7660  Decoder Grad: 0.1723  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][34000/35984] Data 0.000 (0.000) Elapsed 423m 42s (remain 24m 42s) Loss: 0.0599(0.0403) Encoder Grad: 0.2783  Decoder Grad: 0.1508  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][34100/35984] Data 0.000 (0.000) Elapsed 424m 56s (remain 23m 27s) Loss: 0.0183(0.0404) Encoder Grad: 0.4769  Decoder Grad: 0.1670  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][34200/35984] Data 0.000 (0.000) Elapsed 426m 9s (remain 22m 13s) Loss: 0.0459(0.0403) Encoder Grad: 0.3892  Decoder Grad: 0.1508  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][34300/35984] Data 0.000 (0.000) Elapsed 427m 22s (remain 20m 58s) Loss: 0.0328(0.0403) Encoder Grad: 0.1225  Decoder Grad: 0.1013  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][34400/35984] Data 0.000 (0.000) Elapsed 428m 36s (remain 19m 43s) Loss: 0.0353(0.0403) Encoder Grad: 0.2244  Decoder Grad: 0.1228  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][34500/35984] Data 0.000 (0.000) Elapsed 429m 49s (remain 18m 28s) Loss: 0.0374(0.0403) Encoder Grad: 0.4520  Decoder Grad: 0.1228  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][34600/35984] Data 0.000 (0.000) Elapsed 431m 3s (remain 17m 13s) Loss: 0.0407(0.0403) Encoder Grad: 0.3188  Decoder Grad: 0.1403  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][34700/35984] Data 0.000 (0.000) Elapsed 432m 16s (remain 15m 58s) Loss: 0.0549(0.0403) Encoder Grad: 0.1860  Decoder Grad: 0.1273  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][34800/35984] Data 0.000 (0.000) Elapsed 433m 30s (remain 14m 44s) Loss: 0.0312(0.0403) Encoder Grad: 0.5236  Decoder Grad: 0.1846  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][34900/35984] Data 0.000 (0.000) Elapsed 434m 43s (remain 13m 29s) Loss: 0.0601(0.0403) Encoder Grad: 0.2637  Decoder Grad: 0.1474  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][35000/35984] Data 0.000 (0.000) Elapsed 435m 56s (remain 12m 14s) Loss: 0.0500(0.0403) Encoder Grad: 0.2125  Decoder Grad: 0.1010  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][35100/35984] Data 0.000 (0.000) Elapsed 437m 9s (remain 10m 59s) Loss: 0.0219(0.0403) Encoder Grad: 0.1189  Decoder Grad: 0.0889  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][35200/35984] Data 0.000 (0.000) Elapsed 438m 22s (remain 9m 45s) Loss: 0.0291(0.0403) Encoder Grad: 0.2230  Decoder Grad: 0.1377  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][35300/35984] Data 0.000 (0.000) Elapsed 439m 35s (remain 8m 30s) Loss: 0.0327(0.0403) Encoder Grad: 0.2977  Decoder Grad: 0.1224  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][35400/35984] Data 0.000 (0.000) Elapsed 440m 49s (remain 7m 15s) Loss: 0.0479(0.0402) Encoder Grad: 0.1966  Decoder Grad: 0.1357  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][35500/35984] Data 0.000 (0.000) Elapsed 442m 2s (remain 6m 0s) Loss: 0.0512(0.0402) Encoder Grad: 0.2200  Decoder Grad: 0.1210  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][35600/35984] Data 0.000 (0.000) Elapsed 443m 15s (remain 4m 46s) Loss: 0.0257(0.0402) Encoder Grad: 0.1723  Decoder Grad: 0.1016  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][35700/35984] Data 0.000 (0.000) Elapsed 444m 28s (remain 3m 31s) Loss: 0.0454(0.0402) Encoder Grad: 0.2329  Decoder Grad: 0.1388  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][35800/35984] Data 0.000 (0.000) Elapsed 445m 41s (remain 2m 16s) Loss: 0.0177(0.0402) Encoder Grad: 0.1661  Decoder Grad: 0.1184  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][35900/35984] Data 0.000 (0.000) Elapsed 446m 54s (remain 1m 1s) Loss: 0.0275(0.0402) Encoder Grad: 0.2230  Decoder Grad: 0.1381  Encoder LR: 0.000000  Decoder LR: 0.000000
# Epoch: [8][35983/35984] Data 0.000 (0.000) Elapsed 447m 54s (remain 0m 0s) Loss: 0.0298(0.0402) Encoder Grad: 0.2769  Decoder Grad: 0.1718  Encoder LR: 0.000000  Decoder LR: 0.000000
# EVAL: [0/1894] Data 1.709 (1.709) Elapsed 0m 2s (remain 67m 52s)
# EVAL: [100/1894] Data 0.000 (0.017) Elapsed 0m 22s (remain 6m 48s)
# EVAL: [200/1894] Data 0.000 (0.009) Elapsed 0m 43s (remain 6m 8s)
# EVAL: [300/1894] Data 0.000 (0.006) Elapsed 1m 4s (remain 5m 42s)
# EVAL: [400/1894] Data 0.000 (0.004) Elapsed 1m 25s (remain 5m 18s)
# EVAL: [500/1894] Data 0.000 (0.004) Elapsed 1m 46s (remain 4m 55s)
# EVAL: [600/1894] Data 0.000 (0.003) Elapsed 2m 7s (remain 4m 33s)
# EVAL: [700/1894] Data 0.000 (0.003) Elapsed 2m 27s (remain 4m 11s)
# EVAL: [800/1894] Data 0.000 (0.002) Elapsed 2m 48s (remain 3m 50s)
# EVAL: [900/1894] Data 0.000 (0.002) Elapsed 3m 9s (remain 3m 29s)
# EVAL: [1000/1894] Data 0.000 (0.002) Elapsed 3m 30s (remain 3m 7s)
# EVAL: [1100/1894] Data 0.000 (0.002) Elapsed 3m 51s (remain 2m 46s)
# EVAL: [1200/1894] Data 0.000 (0.002) Elapsed 4m 12s (remain 2m 25s)
# EVAL: [1300/1894] Data 0.000 (0.001) Elapsed 4m 33s (remain 2m 4s)
# EVAL: [1400/1894] Data 0.000 (0.001) Elapsed 4m 53s (remain 1m 43s)
# EVAL: [1500/1894] Data 0.000 (0.001) Elapsed 5m 14s (remain 1m 22s)
# EVAL: [1600/1894] Data 0.000 (0.001) Elapsed 5m 35s (remain 1m 1s)
# EVAL: [1700/1894] Data 0.000 (0.001) Elapsed 5m 56s (remain 0m 40s)
# EVAL: [1800/1894] Data 0.000 (0.001) Elapsed 6m 17s (remain 0m 19s)
# EVAL: [1893/1894] Data 0.000 (0.001) Elapsed 6m 36s (remain 0m 0s)
# labels: ['InChI=1S/C17H24N2O4S/c1-12(20)18-13(14-7-6-10-24-14)11-15(21)19-17(16(22)23)8-4-2-3-5-9-17/h6-7,10,13H,2-5,8-9,11H2,1H3,(H,18,20)(H,19,21)(H,22,23)'
#  'InChI=1S/C10H15N5S/c1-7-6-8(9(11)12)14-10(13-7)15-2-4-16-5-3-15/h6H,2-5H2,1H3,(H3,11,12)'
#  'InChI=1S/C16H16Cl2N2O3/c17-12-3-1-11(2-4-12)13-14(18)16(22)20(15(13)21)6-5-19-7-9-23-10-8-19/h1-4H,5-10H2'
#  'InChI=1S/C17H14N4/c1-2-9-21-12-14(20-17(21)6-1)11-19-16-5-3-4-13-10-18-8-7-15(13)16/h1-10,12,19H,11H2'
#  'InChI=1S/C15H18O3/c1-13(2)9-14(3)15(4,18-12(16)17-14)11-8-6-5-7-10(11)13/h5-8H,9H2,1-4H3/t14-,15+/m1/s1']
# preds: ['InChI=1S/C17H24N2O4S/c1-12(20)18-13(14-7-6-10-24-14)11-15(21)19-17(16(22)23)8-4-2-3-5-9-17/h6-7,10,13H,2-5,8-9,11H2,1H3,(H,18,20)(H,19,21)(H,22,23)', 'InChI=1S/C10H15N5S/c1-7-6-8(9(11)12)14-10(13-7)15-2-4-16-5-3-15/h6H,2-5H2,1H3,(H3,11,12)', 'InChI=1S/C16H16Cl2N2O3/c17-12-3-1-11(2-4-12)13-14(18)16(22)20(15(13)21)6-5-19-7-9-23-10-8-19/h1-4H,5-10H2', 'InChI=1S/C17H14N4/c1-2-9-21-12-14(20-17(21)6-1)11-19-16-5-3-4-13-10-18-8-7-15(13)16/h1-10,12,19H,11H2', 'InChI=1S/C15H18O3/c1-13(2)9-14(4)15(5,17-12(16)18-15)11-8-6-7-10(11)13(14)3/h6-8H,9H2,1-4H3/t14-,15+/m1/s1']
# Epoch 8 - avg_train_loss: 0.0402  time: 27272s
# Epoch 8 - Score: 4.2424
# Epoch 8 - Save Best Score: 4.2424 Model
